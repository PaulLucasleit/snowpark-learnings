# %%
# Add module folder to notebook
import os
import sys

from dotenv import find_dotenv
sys.path.append(os.path.dirname(find_dotenv()))

# %%
from snowflake.snowpark import functions
import datetime

from app.snowpark_session.session import snowpark_session

# %%
sp_session = snowpark_session()

# %% [markdown]
# ### Run SQL Commands

# %%
sql = """
select *
from snowflake_sample_data.tpch_sf10.lineitem
limit 1000
"""

df = sp_session.sql(sql)

# %% [markdown]
# ### Show dataframe

# %%
df.show()
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |"L_ORDERKEY"  |"L_PARTKEY"  |"L_SUPPKEY"  |"L_LINENUMBER"  |"L_QUANTITY"  |"L_EXTENDEDPRICE"  |"L_DISCOUNT"  |"L_TAX"  |"L_RETURNFLAG"  |"L_LINESTATUS"  |"L_SHIPDATE"  |"L_COMMITDATE"  |"L_RECEIPTDATE"  |"L_SHIPINSTRUCT"   |"L_SHIPMODE"  |"L_COMMENT"                              |
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |52007138      |1431204      |56219        |1               |7.00          |7945.91            |0.00          |0.06     |A               |F               |1994-12-23    |1994-11-28      |1995-01-02       |COLLECT COD        |REG AIR       |ular packa                               |
# |52007138      |243770       |68773        |2               |27.00         |46271.52           |0.01          |0.03     |R               |F               |1994-11-03    |1994-12-13      |1994-11-05       |DELIVER IN PERSON  |FOB           | the express, regu                       |
# |52007138      |1026811      |1842         |3               |22.00         |38230.72           |0.03          |0.05     |R               |F               |1995-01-04    |1994-11-30      |1995-01-15       |DELIVER IN PERSON  |MAIL          |he furious                               |
# |52007138      |1605770      |5771         |4               |47.00         |78757.43           |0.09          |0.06     |R               |F               |1994-10-25    |1994-12-10      |1994-11-06       |DELIVER IN PERSON  |FOB           |nts. furiously ironic theo               |
# |52007139      |1908893      |33913        |1               |23.00         |43741.40           |0.04          |0.02     |N               |O               |1996-07-03    |1996-07-08      |1996-07-09       |TAKE BACK RETURN   |SHIP          |he carefully ironic deposits             |
# |52007139      |752494       |52495        |2               |12.00         |18557.52           |0.09          |0.07     |N               |O               |1996-08-28    |1996-07-09      |1996-09-02       |TAKE BACK RETURN   |REG AIR       |. quickly unusual                        |
# |52007140      |470967       |95972        |1               |40.00         |77517.60           |0.00          |0.05     |R               |F               |1992-05-02    |1992-05-18      |1992-05-26       |NONE               |TRUCK         | dependencies. special foxes nag furiou  |
# |52007140      |1528088      |28089        |2               |47.00         |52452.47           |0.10          |0.03     |R               |F               |1992-05-29    |1992-04-19      |1992-06-11       |NONE               |MAIL          |ndencies sleep. slyly express package    |
# |52007140      |568699       |18710        |3               |39.00         |68939.13           |0.07          |0.07     |R               |F               |1992-06-10    |1992-05-21      |1992-07-07       |TAKE BACK RETURN   |SHIP          |y special deposits detect warh           |
# |52007141      |1469131      |19160        |1               |1.00          |1100.06            |0.07          |0.06     |R               |F               |1994-04-21    |1994-04-16      |1994-04-25       |DELIVER IN PERSON  |AIR           |re carefull                              |
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
df.collect()
# Out:
# [Row(L_ORDERKEY=58624485, L_PARTKEY=982512, L_SUPPKEY=7522, L_LINENUMBER=7, L_QUANTITY=Decimal('14.00'), L_EXTENDEDPRICE=Decimal('22322.58'), L_DISCOUNT=Decimal('0.09'), L_TAX=Decimal('0.08'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 5, 11), L_COMMITDATE=datetime.date(1997, 5, 4), L_RECEIPTDATE=datetime.date(1997, 5, 31), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='REG AIR', L_COMMENT='uffily. blithely pending dep'),
#  Row(L_ORDERKEY=58624486, L_PARTKEY=1070302, L_SUPPKEY=20323, L_LINENUMBER=1, L_QUANTITY=Decimal('43.00'), L_EXTENDEDPRICE=Decimal('54706.75'), L_DISCOUNT=Decimal('0.06'), L_TAX=Decimal('0.02'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1998, 5, 6), L_COMMITDATE=datetime.date(1998, 5, 16), L_RECEIPTDATE=datetime.date(1998, 5, 20), L_SHIPINSTRUCT='NONE', L_SHIPMODE='SHIP', L_COMMENT=' above the sheaves haggle afte'),
#  Row(L_ORDERKEY=58624486, L_PARTKEY=552563, L_SUPPKEY=77569, L_LINENUMBER=2, L_QUANTITY=Decimal('24.00'), L_EXTENDEDPRICE=Decimal('38772.96'), L_DISCOUNT=Decimal('0.07'), L_TAX=Decimal('0.01'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1998, 6, 22), L_COMMITDATE=datetime.date(1998, 6, 3), L_RECEIPTDATE=datetime.date(1998, 6, 27), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='AIR', L_COMMENT=' the regular, final dinos sleep furiously'),
#  Row(L_ORDERKEY=58624486, L_PARTKEY=925493, L_SUPPKEY=521, L_LINENUMBER=3, L_QUANTITY=Decimal('2.00'), L_EXTENDEDPRICE=Decimal('3036.90'), L_DISCOUNT=Decimal('0.03'), L_TAX=Decimal('0.04'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1998, 5, 8), L_COMMITDATE=datetime.date(1998, 5, 14), L_RECEIPTDATE=datetime.date(1998, 5, 16), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='FOB', L_COMMENT='iously bold deposits are'),
#  Row(L_ORDERKEY=58624486, L_PARTKEY=749590, L_SUPPKEY=24612, L_LINENUMBER=4, L_QUANTITY=Decimal('34.00'), L_EXTENDEDPRICE=Decimal('55745.04'), L_DISCOUNT=Decimal('0.05'), L_TAX=Decimal('0.07'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1998, 7, 21), L_COMMITDATE=datetime.date(1998, 4, 27), L_RECEIPTDATE=datetime.date(1998, 8, 19), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='TRUCK', L_COMMENT='excuses shall haggle blithely. de'),
#  Row(L_ORDERKEY=58624486, L_PARTKEY=351328, L_SUPPKEY=51329, L_LINENUMBER=5, L_QUANTITY=Decimal('33.00'), L_EXTENDEDPRICE=Decimal('45517.23'), L_DISCOUNT=Decimal('0.04'), L_TAX=Decimal('0.02'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1998, 5, 17), L_COMMITDATE=datetime.date(1998, 5, 18), L_RECEIPTDATE=datetime.date(1998, 6, 16), L_SHIPINSTRUCT='NONE', L_SHIPMODE='TRUCK', L_COMMENT='l asymptotes integrate after the'),
#  Row(L_ORDERKEY=58624487, L_PARTKEY=1346802, L_SUPPKEY=71816, L_LINENUMBER=1, L_QUANTITY=Decimal('45.00'), L_EXTENDEDPRICE=Decimal('83193.30'), L_DISCOUNT=Decimal('0.03'), L_TAX=Decimal('0.00'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1993, 8, 21), L_COMMITDATE=datetime.date(1993, 10, 6), L_RECEIPTDATE=datetime.date(1993, 8, 27), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='REG AIR', L_COMMENT='beans run slyly '),
#  Row(L_ORDERKEY=58624512, L_PARTKEY=245390, L_SUPPKEY=20397, L_LINENUMBER=1, L_QUANTITY=Decimal('40.00'), L_EXTENDEDPRICE=Decimal('53415.20'), L_DISCOUNT=Decimal('0.10'), L_TAX=Decimal('0.01'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 2, 7), L_COMMITDATE=datetime.date(1993, 12, 30), L_RECEIPTDATE=datetime.date(1994, 2, 23), L_SHIPINSTRUCT='NONE', L_SHIPMODE='TRUCK', L_COMMENT='ly regular packages. furiously special acco'),
#  Row(L_ORDERKEY=58624513, L_PARTKEY=1066367, L_SUPPKEY=41398, L_LINENUMBER=1, L_QUANTITY=Decimal('36.00'), L_EXTENDEDPRICE=Decimal('47999.16'), L_DISCOUNT=Decimal('0.08'), L_TAX=Decimal('0.06'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1993, 5, 31), L_COMMITDATE=datetime.date(1993, 7, 12), L_RECEIPTDATE=datetime.date(1993, 6, 6), L_SHIPINSTRUCT='NONE', L_SHIPMODE='RAIL', L_COMMENT='are furiousl'),
#  Row(L_ORDERKEY=58624513, L_PARTKEY=427554, L_SUPPKEY=77563, L_LINENUMBER=2, L_QUANTITY=Decimal('29.00'), L_EXTENDEDPRICE=Decimal('42964.37'), L_DISCOUNT=Decimal('0.03'), L_TAX=Decimal('0.03'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1993, 7, 27), L_COMMITDATE=datetime.date(1993, 6, 8), L_RECEIPTDATE=datetime.date(1993, 8, 10), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='AIR', L_COMMENT='counts boost accounts. quickly regular the'),
#  Row(L_ORDERKEY=58624513, L_PARTKEY=1890396, L_SUPPKEY=15415, L_LINENUMBER=3, L_QUANTITY=Decimal('16.00'), L_EXTENDEDPRICE=Decimal('22180.80'), L_DISCOUNT=Decimal('0.01'), L_TAX=Decimal('0.03'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1993, 6, 22), L_COMMITDATE=datetime.date(1993, 6, 7), L_RECEIPTDATE=datetime.date(1993, 7, 21), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='AIR', L_COMMENT='as was. finally regular requ'),
#  Row(L_ORDERKEY=58624513, L_PARTKEY=1871154, L_SUPPKEY=21191, L_LINENUMBER=4, L_QUANTITY=Decimal('45.00'), L_EXTENDEDPRICE=Decimal('50627.70'), L_DISCOUNT=Decimal('0.01'), L_TAX=Decimal('0.03'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1993, 7, 8), L_COMMITDATE=datetime.date(1993, 7, 29), L_RECEIPTDATE=datetime.date(1993, 7, 29), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='MAIL', L_COMMENT='uts haggle furiou'),
#  Row(L_ORDERKEY=58624514, L_PARTKEY=1290317, L_SUPPKEY=15330, L_LINENUMBER=1, L_QUANTITY=Decimal('10.00'), L_EXTENDEDPRICE=Decimal('13072.50'), L_DISCOUNT=Decimal('0.10'), L_TAX=Decimal('0.06'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 2, 15), L_COMMITDATE=datetime.date(1997, 2, 10), L_RECEIPTDATE=datetime.date(1997, 3, 5), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='REG AIR', L_COMMENT='e slyly fluffily pending pains; slyly pe'),
#  Row(L_ORDERKEY=58624514, L_PARTKEY=343333, L_SUPPKEY=93340, L_LINENUMBER=2, L_QUANTITY=Decimal('2.00'), L_EXTENDEDPRICE=Decimal('2752.64'), L_DISCOUNT=Decimal('0.02'), L_TAX=Decimal('0.02'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 2, 17), L_COMMITDATE=datetime.date(1997, 1, 12), L_RECEIPTDATE=datetime.date(1997, 3, 18), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='SHIP', L_COMMENT='ggle furiously fluffily express '),
#  Row(L_ORDERKEY=58624514, L_PARTKEY=394578, L_SUPPKEY=44585, L_LINENUMBER=3, L_QUANTITY=Decimal('49.00'), L_EXTENDEDPRICE=Decimal('81955.44'), L_DISCOUNT=Decimal('0.07'), L_TAX=Decimal('0.07'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1996, 12, 30), L_COMMITDATE=datetime.date(1997, 1, 25), L_RECEIPTDATE=datetime.date(1997, 1, 29), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='TRUCK', L_COMMENT='lly pending deposits! blithely '),
#  Row(L_ORDERKEY=58624514, L_PARTKEY=1658418, L_SUPPKEY=83435, L_LINENUMBER=4, L_QUANTITY=Decimal('21.00'), L_EXTENDEDPRICE=Decimal('28902.93'), L_DISCOUNT=Decimal('0.01'), L_TAX=Decimal('0.03'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 1, 6), L_COMMITDATE=datetime.date(1997, 2, 24), L_RECEIPTDATE=datetime.date(1997, 2, 5), L_SHIPINSTRUCT='NONE', L_SHIPMODE='REG AIR', L_COMMENT=' packages solve for the blithel'),
#  Row(L_ORDERKEY=58624514, L_PARTKEY=1022914, L_SUPPKEY=47925, L_LINENUMBER=5, L_QUANTITY=Decimal('47.00'), L_EXTENDEDPRICE=Decimal('86332.42'), L_DISCOUNT=Decimal('0.09'), L_TAX=Decimal('0.07'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 1, 22), L_COMMITDATE=datetime.date(1997, 1, 22), L_RECEIPTDATE=datetime.date(1997, 1, 28), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='MAIL', L_COMMENT='g the unusual, ironic waters sl'),
#  Row(L_ORDERKEY=58624515, L_PARTKEY=414400, L_SUPPKEY=89413, L_LINENUMBER=1, L_QUANTITY=Decimal('9.00'), L_EXTENDEDPRICE=Decimal('11829.42'), L_DISCOUNT=Decimal('0.09'), L_TAX=Decimal('0.03'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 8, 21), L_COMMITDATE=datetime.date(1997, 7, 28), L_RECEIPTDATE=datetime.date(1997, 9, 18), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='REG AIR', L_COMMENT='ar accounts wake carefully al'),
#  Row(L_ORDERKEY=58624515, L_PARTKEY=806327, L_SUPPKEY=31336, L_LINENUMBER=2, L_QUANTITY=Decimal('35.00'), L_EXTENDEDPRICE=Decimal('43164.80'), L_DISCOUNT=Decimal('0.00'), L_TAX=Decimal('0.08'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 8, 19), L_COMMITDATE=datetime.date(1997, 7, 23), L_RECEIPTDATE=datetime.date(1997, 9, 10), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='MAIL', L_COMMENT='riously eve'),
#  Row(L_ORDERKEY=58624515, L_PARTKEY=1930559, L_SUPPKEY=80598, L_LINENUMBER=3, L_QUANTITY=Decimal('7.00'), L_EXTENDEDPRICE=Decimal('11126.22'), L_DISCOUNT=Decimal('0.03'), L_TAX=Decimal('0.04'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 9, 23), L_COMMITDATE=datetime.date(1997, 7, 23), L_RECEIPTDATE=datetime.date(1997, 9, 29), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='MAIL', L_COMMENT='ymptotes! regular, bold foxes boost ca'),
#  Row(L_ORDERKEY=58624515, L_PARTKEY=897584, L_SUPPKEY=72609, L_LINENUMBER=4, L_QUANTITY=Decimal('5.00'), L_EXTENDEDPRICE=Decimal('7907.70'), L_DISCOUNT=Decimal('0.02'), L_TAX=Decimal('0.06'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 8, 11), L_COMMITDATE=datetime.date(1997, 8, 4), L_RECEIPTDATE=datetime.date(1997, 9, 10), L_SHIPINSTRUCT='NONE', L_SHIPMODE='FOB', L_COMMENT='he furiously ironic requests dete'),
#  Row(L_ORDERKEY=58624515, L_PARTKEY=1685806, L_SUPPKEY=35839, L_LINENUMBER=5, L_QUANTITY=Decimal('49.00'), L_EXTENDEDPRICE=Decimal('87794.28'), L_DISCOUNT=Decimal('0.06'), L_TAX=Decimal('0.03'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 9, 12), L_COMMITDATE=datetime.date(1997, 8, 27), L_RECEIPTDATE=datetime.date(1997, 9, 15), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='AIR', L_COMMENT='iously. blithely express pack'),
#  Row(L_ORDERKEY=58624515, L_PARTKEY=1336598, L_SUPPKEY=61612, L_LINENUMBER=6, L_QUANTITY=Decimal('38.00'), L_EXTENDEDPRICE=Decimal('62112.14'), L_DISCOUNT=Decimal('0.10'), L_TAX=Decimal('0.05'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 6, 16), L_COMMITDATE=datetime.date(1997, 7, 30), L_RECEIPTDATE=datetime.date(1997, 6, 28), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='TRUCK', L_COMMENT='r packages. furiously '),
#  Row(L_ORDERKEY=58624516, L_PARTKEY=1233201, L_SUPPKEY=33202, L_LINENUMBER=1, L_QUANTITY=Decimal('49.00'), L_EXTENDEDPRICE=Decimal('55572.86'), L_DISCOUNT=Decimal('0.10'), L_TAX=Decimal('0.07'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1993, 1, 1), L_COMMITDATE=datetime.date(1992, 11, 1), L_RECEIPTDATE=datetime.date(1993, 1, 6), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='SHIP', L_COMMENT='ly among the regular, '),
#  Row(L_ORDERKEY=58624516, L_PARTKEY=407275, L_SUPPKEY=57284, L_LINENUMBER=2, L_QUANTITY=Decimal('5.00'), L_EXTENDEDPRICE=Decimal('5911.25'), L_DISCOUNT=Decimal('0.00'), L_TAX=Decimal('0.06'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1992, 9, 26), L_COMMITDATE=datetime.date(1992, 12, 9), L_RECEIPTDATE=datetime.date(1992, 10, 13), L_SHIPINSTRUCT='NONE', L_SHIPMODE='RAIL', L_COMMENT='elets. slyly ironic'),
#  Row(L_ORDERKEY=58624516, L_PARTKEY=1056945, L_SUPPKEY=31976, L_LINENUMBER=3, L_QUANTITY=Decimal('22.00'), L_EXTENDEDPRICE=Decimal('41841.58'), L_DISCOUNT=Decimal('0.03'), L_TAX=Decimal('0.00'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1992, 11, 25), L_COMMITDATE=datetime.date(1992, 10, 30), L_RECEIPTDATE=datetime.date(1992, 11, 26), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='REG AIR', L_COMMENT='s. slyly i'),
#  Row(L_ORDERKEY=58624516, L_PARTKEY=66325, L_SUPPKEY=41326, L_LINENUMBER=4, L_QUANTITY=Decimal('41.00'), L_EXTENDEDPRICE=Decimal('52944.12'), L_DISCOUNT=Decimal('0.02'), L_TAX=Decimal('0.02'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1993, 1, 3), L_COMMITDATE=datetime.date(1992, 11, 30), L_RECEIPTDATE=datetime.date(1993, 1, 31), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='AIR', L_COMMENT='ctions. thin instructions dazzle c'),
#  Row(L_ORDERKEY=58624517, L_PARTKEY=670016, L_SUPPKEY=70017, L_LINENUMBER=1, L_QUANTITY=Decimal('41.00'), L_EXTENDEDPRICE=Decimal('40425.18'), L_DISCOUNT=Decimal('0.03'), L_TAX=Decimal('0.07'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1993, 12, 15), L_COMMITDATE=datetime.date(1994, 2, 14), L_RECEIPTDATE=datetime.date(1993, 12, 23), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='MAIL', L_COMMENT='ly silent requests along t'),
#  Row(L_ORDERKEY=58624517, L_PARTKEY=945301, L_SUPPKEY=20329, L_LINENUMBER=2, L_QUANTITY=Decimal('27.00'), L_EXTENDEDPRICE=Decimal('36349.02'), L_DISCOUNT=Decimal('0.06'), L_TAX=Decimal('0.07'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 2, 5), L_COMMITDATE=datetime.date(1994, 2, 7), L_RECEIPTDATE=datetime.date(1994, 2, 16), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='TRUCK', L_COMMENT='ans: blithely dogged r'),
#  Row(L_ORDERKEY=58624517, L_PARTKEY=1659734, L_SUPPKEY=9767, L_LINENUMBER=3, L_QUANTITY=Decimal('24.00'), L_EXTENDEDPRICE=Decimal('40647.60'), L_DISCOUNT=Decimal('0.04'), L_TAX=Decimal('0.06'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1993, 12, 9), L_COMMITDATE=datetime.date(1994, 2, 5), L_RECEIPTDATE=datetime.date(1994, 1, 5), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='RAIL', L_COMMENT='longside of the carefully ironic frets. fur'),
#  Row(L_ORDERKEY=58624517, L_PARTKEY=1140969, L_SUPPKEY=16003, L_LINENUMBER=4, L_QUANTITY=Decimal('37.00'), L_EXTENDEDPRICE=Decimal('74366.67'), L_DISCOUNT=Decimal('0.05'), L_TAX=Decimal('0.02'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 2, 1), L_COMMITDATE=datetime.date(1994, 1, 17), L_RECEIPTDATE=datetime.date(1994, 2, 7), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='MAIL', L_COMMENT='ns. slyly regul'),
#  Row(L_ORDERKEY=58624517, L_PARTKEY=261215, L_SUPPKEY=86218, L_LINENUMBER=5, L_QUANTITY=Decimal('15.00'), L_EXTENDEDPRICE=Decimal('17643.00'), L_DISCOUNT=Decimal('0.09'), L_TAX=Decimal('0.06'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 2, 11), L_COMMITDATE=datetime.date(1994, 2, 10), L_RECEIPTDATE=datetime.date(1994, 2, 28), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='FOB', L_COMMENT='s. busily regular platelets cajol'),
#  Row(L_ORDERKEY=58624517, L_PARTKEY=238996, L_SUPPKEY=38997, L_LINENUMBER=6, L_QUANTITY=Decimal('38.00'), L_EXTENDEDPRICE=Decimal('73529.24'), L_DISCOUNT=Decimal('0.01'), L_TAX=Decimal('0.01'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 3, 17), L_COMMITDATE=datetime.date(1993, 12, 26), L_RECEIPTDATE=datetime.date(1994, 4, 10), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='SHIP', L_COMMENT='iously-- fluff'),
#  Row(L_ORDERKEY=58624517, L_PARTKEY=800328, L_SUPPKEY=25337, L_LINENUMBER=7, L_QUANTITY=Decimal('20.00'), L_EXTENDEDPRICE=Decimal('24565.60'), L_DISCOUNT=Decimal('0.07'), L_TAX=Decimal('0.03'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1993, 12, 1), L_COMMITDATE=datetime.date(1994, 1, 21), L_RECEIPTDATE=datetime.date(1993, 12, 24), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='FOB', L_COMMENT='quickly regular accounts are blithely '),
#  Row(L_ORDERKEY=58624518, L_PARTKEY=1099374, L_SUPPKEY=49395, L_LINENUMBER=1, L_QUANTITY=Decimal('46.00'), L_EXTENDEDPRICE=Decimal('63172.72'), L_DISCOUNT=Decimal('0.02'), L_TAX=Decimal('0.08'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 2, 2), L_COMMITDATE=datetime.date(1997, 3, 2), L_RECEIPTDATE=datetime.date(1997, 2, 26), L_SHIPINSTRUCT='NONE', L_SHIPMODE='SHIP', L_COMMENT='es hinder furiously quick'),
#  Row(L_ORDERKEY=58624518, L_PARTKEY=1173286, L_SUPPKEY=48320, L_LINENUMBER=2, L_QUANTITY=Decimal('46.00'), L_EXTENDEDPRICE=Decimal('62524.58'), L_DISCOUNT=Decimal('0.02'), L_TAX=Decimal('0.03'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 3, 20), L_COMMITDATE=datetime.date(1997, 2, 24), L_RECEIPTDATE=datetime.date(1997, 4, 10), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='RAIL', L_COMMENT=' the furiously f'),
#  Row(L_ORDERKEY=58624518, L_PARTKEY=1405200, L_SUPPKEY=80243, L_LINENUMBER=3, L_QUANTITY=Decimal('40.00'), L_EXTENDEDPRICE=Decimal('44205.20'), L_DISCOUNT=Decimal('0.07'), L_TAX=Decimal('0.04'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 1, 9), L_COMMITDATE=datetime.date(1997, 1, 24), L_RECEIPTDATE=datetime.date(1997, 1, 14), L_SHIPINSTRUCT='NONE', L_SHIPMODE='REG AIR', L_COMMENT='y pending packages haggle carefully'),
#  Row(L_ORDERKEY=58624518, L_PARTKEY=1188959, L_SUPPKEY=13971, L_LINENUMBER=4, L_QUANTITY=Decimal('17.00'), L_EXTENDEDPRICE=Decimal('34814.30'), L_DISCOUNT=Decimal('0.04'), L_TAX=Decimal('0.07'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 4, 4), L_COMMITDATE=datetime.date(1997, 3, 11), L_RECEIPTDATE=datetime.date(1997, 4, 30), L_SHIPINSTRUCT='NONE', L_SHIPMODE='AIR', L_COMMENT='nal, regular '),
#  Row(L_ORDERKEY=58624518, L_PARTKEY=833354, L_SUPPKEY=83371, L_LINENUMBER=5, L_QUANTITY=Decimal('40.00'), L_EXTENDEDPRICE=Decimal('51492.40'), L_DISCOUNT=Decimal('0.00'), L_TAX=Decimal('0.07'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 1, 11), L_COMMITDATE=datetime.date(1997, 1, 19), L_RECEIPTDATE=datetime.date(1997, 2, 7), L_SHIPINSTRUCT='NONE', L_SHIPMODE='FOB', L_COMMENT='ckly express packages wake furiously. c'),
#  Row(L_ORDERKEY=58624519, L_PARTKEY=1899878, L_SUPPKEY=24897, L_LINENUMBER=1, L_QUANTITY=Decimal('13.00'), L_EXTENDEDPRICE=Decimal('24411.14'), L_DISCOUNT=Decimal('0.03'), L_TAX=Decimal('0.03'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 6, 17), L_COMMITDATE=datetime.date(1997, 7, 10), L_RECEIPTDATE=datetime.date(1997, 7, 15), L_SHIPINSTRUCT='NONE', L_SHIPMODE='TRUCK', L_COMMENT='ackages use. slyly pending in'),
#  Row(L_ORDERKEY=58624519, L_PARTKEY=1235801, L_SUPPKEY=60814, L_LINENUMBER=2, L_QUANTITY=Decimal('11.00'), L_EXTENDEDPRICE=Decimal('19104.14'), L_DISCOUNT=Decimal('0.08'), L_TAX=Decimal('0.06'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 6, 23), L_COMMITDATE=datetime.date(1997, 5, 28), L_RECEIPTDATE=datetime.date(1997, 7, 2), L_SHIPINSTRUCT='NONE', L_SHIPMODE='TRUCK', L_COMMENT='uriously u'),
#  Row(L_ORDERKEY=58624519, L_PARTKEY=100454, L_SUPPKEY=25456, L_LINENUMBER=3, L_QUANTITY=Decimal('11.00'), L_EXTENDEDPRICE=Decimal('15998.95'), L_DISCOUNT=Decimal('0.00'), L_TAX=Decimal('0.06'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 8, 7), L_COMMITDATE=datetime.date(1997, 5, 30), L_RECEIPTDATE=datetime.date(1997, 8, 24), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='AIR', L_COMMENT='hely regular, ir'),
#  Row(L_ORDERKEY=58624519, L_PARTKEY=325195, L_SUPPKEY=50199, L_LINENUMBER=4, L_QUANTITY=Decimal('9.00'), L_EXTENDEDPRICE=Decimal('10981.62'), L_DISCOUNT=Decimal('0.10'), L_TAX=Decimal('0.02'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 6, 18), L_COMMITDATE=datetime.date(1997, 6, 20), L_RECEIPTDATE=datetime.date(1997, 6, 24), L_SHIPINSTRUCT='NONE', L_SHIPMODE='AIR', L_COMMENT='er the blithely regular ac'),
#  Row(L_ORDERKEY=58624519, L_PARTKEY=1548761, L_SUPPKEY=23807, L_LINENUMBER=5, L_QUANTITY=Decimal('1.00'), L_EXTENDEDPRICE=Decimal('1809.69'), L_DISCOUNT=Decimal('0.01'), L_TAX=Decimal('0.07'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 8, 13), L_COMMITDATE=datetime.date(1997, 6, 12), L_RECEIPTDATE=datetime.date(1997, 9, 9), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='TRUCK', L_COMMENT='hes! furiously final depende'),
#  Row(L_ORDERKEY=58624519, L_PARTKEY=14070, L_SUPPKEY=89071, L_LINENUMBER=6, L_QUANTITY=Decimal('7.00'), L_EXTENDEDPRICE=Decimal('6888.49'), L_DISCOUNT=Decimal('0.01'), L_TAX=Decimal('0.04'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 6, 24), L_COMMITDATE=datetime.date(1997, 6, 25), L_RECEIPTDATE=datetime.date(1997, 7, 22), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='REG AIR', L_COMMENT=' the blithely regular pa'),
#  Row(L_ORDERKEY=58624544, L_PARTKEY=1615405, L_SUPPKEY=40422, L_LINENUMBER=1, L_QUANTITY=Decimal('16.00'), L_EXTENDEDPRICE=Decimal('21125.12'), L_DISCOUNT=Decimal('0.09'), L_TAX=Decimal('0.01'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 3, 9), L_COMMITDATE=datetime.date(1997, 4, 29), L_RECEIPTDATE=datetime.date(1997, 3, 24), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='AIR', L_COMMENT='symptotes alongside of'),
#  Row(L_ORDERKEY=58624544, L_PARTKEY=106132, L_SUPPKEY=81136, L_LINENUMBER=2, L_QUANTITY=Decimal('19.00'), L_EXTENDEDPRICE=Decimal('21624.47'), L_DISCOUNT=Decimal('0.10'), L_TAX=Decimal('0.07'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 6, 9), L_COMMITDATE=datetime.date(1997, 5, 7), L_RECEIPTDATE=datetime.date(1997, 7, 5), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='AIR', L_COMMENT='ep against the excuses?'),
#  Row(L_ORDERKEY=58624544, L_PARTKEY=1748469, L_SUPPKEY=23521, L_LINENUMBER=3, L_QUANTITY=Decimal('26.00'), L_EXTENDEDPRICE=Decimal('39451.88'), L_DISCOUNT=Decimal('0.08'), L_TAX=Decimal('0.03'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 3, 26), L_COMMITDATE=datetime.date(1997, 5, 7), L_RECEIPTDATE=datetime.date(1997, 4, 13), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='FOB', L_COMMENT='fully. slyly '),
#  Row(L_ORDERKEY=58624544, L_PARTKEY=502981, L_SUPPKEY=52992, L_LINENUMBER=4, L_QUANTITY=Decimal('15.00'), L_EXTENDEDPRICE=Decimal('29759.40'), L_DISCOUNT=Decimal('0.01'), L_TAX=Decimal('0.01'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 5, 9), L_COMMITDATE=datetime.date(1997, 4, 14), L_RECEIPTDATE=datetime.date(1997, 5, 19), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='MAIL', L_COMMENT='ending req'),
#  Row(L_ORDERKEY=58624544, L_PARTKEY=1595514, L_SUPPKEY=95515, L_LINENUMBER=5, L_QUANTITY=Decimal('3.00'), L_EXTENDEDPRICE=Decimal('4828.32'), L_DISCOUNT=Decimal('0.07'), L_TAX=Decimal('0.05'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 4, 1), L_COMMITDATE=datetime.date(1997, 3, 23), L_RECEIPTDATE=datetime.date(1997, 4, 16), L_SHIPINSTRUCT='NONE', L_SHIPMODE='MAIL', L_COMMENT='ular foxes. silent instructions mold '),
#  Row(L_ORDERKEY=58624544, L_PARTKEY=1795459, L_SUPPKEY=20477, L_LINENUMBER=6, L_QUANTITY=Decimal('15.00'), L_EXTENDEDPRICE=Decimal('23315.55'), L_DISCOUNT=Decimal('0.05'), L_TAX=Decimal('0.00'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 5, 16), L_COMMITDATE=datetime.date(1997, 4, 21), L_RECEIPTDATE=datetime.date(1997, 6, 3), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='REG AIR', L_COMMENT='ep furiously ironic accounts. carefu'),
#  Row(L_ORDERKEY=58624545, L_PARTKEY=1430049, L_SUPPKEY=55064, L_LINENUMBER=1, L_QUANTITY=Decimal('38.00'), L_EXTENDEDPRICE=Decimal('37200.86'), L_DISCOUNT=Decimal('0.03'), L_TAX=Decimal('0.01'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1993, 2, 17), L_COMMITDATE=datetime.date(1992, 11, 25), L_RECEIPTDATE=datetime.date(1993, 3, 18), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='REG AIR', L_COMMENT='st slyly along the regular reques'),
#  Row(L_ORDERKEY=58624545, L_PARTKEY=831181, L_SUPPKEY=31182, L_LINENUMBER=2, L_QUANTITY=Decimal('17.00'), L_EXTENDEDPRICE=Decimal('18906.38'), L_DISCOUNT=Decimal('0.02'), L_TAX=Decimal('0.05'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1992, 10, 26), L_COMMITDATE=datetime.date(1992, 12, 30), L_RECEIPTDATE=datetime.date(1992, 11, 10), L_SHIPINSTRUCT='NONE', L_SHIPMODE='AIR', L_COMMENT='fully among the furious'),
#  Row(L_ORDERKEY=58624546, L_PARTKEY=66477, L_SUPPKEY=41478, L_LINENUMBER=1, L_QUANTITY=Decimal('1.00'), L_EXTENDEDPRICE=Decimal('1443.47'), L_DISCOUNT=Decimal('0.01'), L_TAX=Decimal('0.00'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 5, 31), L_COMMITDATE=datetime.date(1994, 4, 13), L_RECEIPTDATE=datetime.date(1994, 6, 7), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='RAIL', L_COMMENT='ickly final requests are slyl'),
#  Row(L_ORDERKEY=58624546, L_PARTKEY=1277856, L_SUPPKEY=2869, L_LINENUMBER=2, L_QUANTITY=Decimal('5.00'), L_EXTENDEDPRICE=Decimal('9168.95'), L_DISCOUNT=Decimal('0.10'), L_TAX=Decimal('0.02'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 6, 17), L_COMMITDATE=datetime.date(1994, 5, 10), L_RECEIPTDATE=datetime.date(1994, 6, 21), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='MAIL', L_COMMENT='nst the quickly idle requests. sl'),
#  Row(L_ORDERKEY=58624546, L_PARTKEY=922731, L_SUPPKEY=47741, L_LINENUMBER=3, L_QUANTITY=Decimal('43.00'), L_EXTENDEDPRICE=Decimal('75408.67'), L_DISCOUNT=Decimal('0.05'), L_TAX=Decimal('0.06'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 4, 9), L_COMMITDATE=datetime.date(1994, 4, 29), L_RECEIPTDATE=datetime.date(1994, 5, 2), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='TRUCK', L_COMMENT='ously about the furiously '),
#  Row(L_ORDERKEY=58624546, L_PARTKEY=325822, L_SUPPKEY=75829, L_LINENUMBER=4, L_QUANTITY=Decimal('46.00'), L_EXTENDEDPRICE=Decimal('84999.26'), L_DISCOUNT=Decimal('0.00'), L_TAX=Decimal('0.06'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 5, 22), L_COMMITDATE=datetime.date(1994, 4, 28), L_RECEIPTDATE=datetime.date(1994, 6, 16), L_SHIPINSTRUCT='NONE', L_SHIPMODE='RAIL', L_COMMENT='leep. even deposits haggle slyly afte'),
#  Row(L_ORDERKEY=58624547, L_PARTKEY=1531437, L_SUPPKEY=56453, L_LINENUMBER=1, L_QUANTITY=Decimal('34.00'), L_EXTENDEDPRICE=Decimal('49924.24'), L_DISCOUNT=Decimal('0.05'), L_TAX=Decimal('0.02'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1993, 10, 15), L_COMMITDATE=datetime.date(1993, 9, 24), L_RECEIPTDATE=datetime.date(1993, 11, 10), L_SHIPINSTRUCT='NONE', L_SHIPMODE='FOB', L_COMMENT='. slyly even pinto beans so'),
#  Row(L_ORDERKEY=58624547, L_PARTKEY=860831, L_SUPPKEY=35856, L_LINENUMBER=2, L_QUANTITY=Decimal('29.00'), L_EXTENDEDPRICE=Decimal('51961.91'), L_DISCOUNT=Decimal('0.04'), L_TAX=Decimal('0.02'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1993, 12, 10), L_COMMITDATE=datetime.date(1993, 10, 16), L_RECEIPTDATE=datetime.date(1994, 1, 2), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='RAIL', L_COMMENT='ely even ide'),
#  Row(L_ORDERKEY=58624547, L_PARTKEY=1971549, L_SUPPKEY=21588, L_LINENUMBER=3, L_QUANTITY=Decimal('42.00'), L_EXTENDEDPRICE=Decimal('68058.90'), L_DISCOUNT=Decimal('0.01'), L_TAX=Decimal('0.05'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1993, 10, 3), L_COMMITDATE=datetime.date(1993, 10, 9), L_RECEIPTDATE=datetime.date(1993, 11, 2), L_SHIPINSTRUCT='NONE', L_SHIPMODE='MAIL', L_COMMENT='dle after the quiet, '),
#  Row(L_ORDERKEY=58624547, L_PARTKEY=1818183, L_SUPPKEY=43202, L_LINENUMBER=4, L_QUANTITY=Decimal('35.00'), L_EXTENDEDPRICE=Decimal('38538.15'), L_DISCOUNT=Decimal('0.05'), L_TAX=Decimal('0.02'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1993, 9, 23), L_COMMITDATE=datetime.date(1993, 11, 14), L_RECEIPTDATE=datetime.date(1993, 10, 22), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='FOB', L_COMMENT='ts cajole bli'),
#  Row(L_ORDERKEY=58624547, L_PARTKEY=200572, L_SUPPKEY=50577, L_LINENUMBER=5, L_QUANTITY=Decimal('29.00'), L_EXTENDEDPRICE=Decimal('42704.24'), L_DISCOUNT=Decimal('0.04'), L_TAX=Decimal('0.00'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1993, 10, 29), L_COMMITDATE=datetime.date(1993, 11, 12), L_RECEIPTDATE=datetime.date(1993, 11, 6), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='FOB', L_COMMENT='arefully pending de'),
#  Row(L_ORDERKEY=58624548, L_PARTKEY=1918198, L_SUPPKEY=43218, L_LINENUMBER=1, L_QUANTITY=Decimal('5.00'), L_EXTENDEDPRICE=Decimal('6080.50'), L_DISCOUNT=Decimal('0.01'), L_TAX=Decimal('0.06'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1993, 1, 17), L_COMMITDATE=datetime.date(1993, 3, 30), L_RECEIPTDATE=datetime.date(1993, 2, 14), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='AIR', L_COMMENT='xpress instruct'),
#  Row(L_ORDERKEY=58624549, L_PARTKEY=1849797, L_SUPPKEY=74816, L_LINENUMBER=1, L_QUANTITY=Decimal('41.00'), L_EXTENDEDPRICE=Decimal('71614.70'), L_DISCOUNT=Decimal('0.08'), L_TAX=Decimal('0.02'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 6, 25), L_COMMITDATE=datetime.date(1997, 7, 29), L_RECEIPTDATE=datetime.date(1997, 7, 24), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='RAIL', L_COMMENT=' regular requests. final requests'),
#  Row(L_ORDERKEY=58624549, L_PARTKEY=1525158, L_SUPPKEY=204, L_LINENUMBER=2, L_QUANTITY=Decimal('1.00'), L_EXTENDEDPRICE=Decimal('1183.08'), L_DISCOUNT=Decimal('0.01'), L_TAX=Decimal('0.01'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 7, 9), L_COMMITDATE=datetime.date(1997, 8, 30), L_RECEIPTDATE=datetime.date(1997, 7, 24), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='RAIL', L_COMMENT=' silent courts haggle carefully acr'),
#  Row(L_ORDERKEY=58624549, L_PARTKEY=1325873, L_SUPPKEY=75900, L_LINENUMBER=3, L_QUANTITY=Decimal('39.00'), L_EXTENDEDPRICE=Decimal('74053.59'), L_DISCOUNT=Decimal('0.06'), L_TAX=Decimal('0.06'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 7, 6), L_COMMITDATE=datetime.date(1997, 7, 22), L_RECEIPTDATE=datetime.date(1997, 7, 26), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='SHIP', L_COMMENT='al deposits boost carefull'),
#  Row(L_ORDERKEY=58624549, L_PARTKEY=1931972, L_SUPPKEY=7030, L_LINENUMBER=4, L_QUANTITY=Decimal('47.00'), L_EXTENDEDPRICE=Decimal('94182.36'), L_DISCOUNT=Decimal('0.06'), L_TAX=Decimal('0.08'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 6, 28), L_COMMITDATE=datetime.date(1997, 7, 6), L_RECEIPTDATE=datetime.date(1997, 7, 14), L_SHIPINSTRUCT='NONE', L_SHIPMODE='FOB', L_COMMENT='ly ironic pinto beans. sl'),
#  Row(L_ORDERKEY=58624549, L_PARTKEY=649253, L_SUPPKEY=49254, L_LINENUMBER=5, L_QUANTITY=Decimal('34.00'), L_EXTENDEDPRICE=Decimal('40875.48'), L_DISCOUNT=Decimal('0.05'), L_TAX=Decimal('0.02'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 7, 2), L_COMMITDATE=datetime.date(1997, 8, 2), L_RECEIPTDATE=datetime.date(1997, 7, 27), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='AIR', L_COMMENT='telets. slyly ironic n'),
#  Row(L_ORDERKEY=58624549, L_PARTKEY=1985246, L_SUPPKEY=85247, L_LINENUMBER=6, L_QUANTITY=Decimal('37.00'), L_EXTENDEDPRICE=Decimal('49252.55'), L_DISCOUNT=Decimal('0.07'), L_TAX=Decimal('0.02'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 7, 1), L_COMMITDATE=datetime.date(1997, 8, 3), L_RECEIPTDATE=datetime.date(1997, 7, 4), L_SHIPINSTRUCT='NONE', L_SHIPMODE='MAIL', L_COMMENT='posits wake slyly along the pending ideas.'),
#  Row(L_ORDERKEY=58624549, L_PARTKEY=14134, L_SUPPKEY=64135, L_LINENUMBER=7, L_QUANTITY=Decimal('38.00'), L_EXTENDEDPRICE=Decimal('39828.94'), L_DISCOUNT=Decimal('0.08'), L_TAX=Decimal('0.00'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 8, 16), L_COMMITDATE=datetime.date(1997, 7, 7), L_RECEIPTDATE=datetime.date(1997, 8, 31), L_SHIPINSTRUCT='NONE', L_SHIPMODE='RAIL', L_COMMENT='packages. packages among t'),
#  Row(L_ORDERKEY=58624550, L_PARTKEY=1537163, L_SUPPKEY=12209, L_LINENUMBER=1, L_QUANTITY=Decimal('35.00'), L_EXTENDEDPRICE=Decimal('42003.15'), L_DISCOUNT=Decimal('0.01'), L_TAX=Decimal('0.06'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1992, 11, 29), L_COMMITDATE=datetime.date(1993, 1, 3), L_RECEIPTDATE=datetime.date(1992, 12, 1), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='FOB', L_COMMENT='uriously accor'),
#  Row(L_ORDERKEY=58624550, L_PARTKEY=1097248, L_SUPPKEY=72279, L_LINENUMBER=2, L_QUANTITY=Decimal('9.00'), L_EXTENDEDPRICE=Decimal('11206.71'), L_DISCOUNT=Decimal('0.00'), L_TAX=Decimal('0.06'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1992, 11, 12), L_COMMITDATE=datetime.date(1992, 12, 14), L_RECEIPTDATE=datetime.date(1992, 11, 20), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='TRUCK', L_COMMENT='ironic account'),
#  Row(L_ORDERKEY=58624550, L_PARTKEY=1438882, L_SUPPKEY=38883, L_LINENUMBER=3, L_QUANTITY=Decimal('23.00'), L_EXTENDEDPRICE=Decimal('41878.63'), L_DISCOUNT=Decimal('0.09'), L_TAX=Decimal('0.03'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1992, 11, 15), L_COMMITDATE=datetime.date(1993, 1, 3), L_RECEIPTDATE=datetime.date(1992, 12, 12), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='AIR', L_COMMENT='he fluffily ir'),
#  Row(L_ORDERKEY=58624550, L_PARTKEY=1281393, L_SUPPKEY=56430, L_LINENUMBER=4, L_QUANTITY=Decimal('29.00'), L_EXTENDEDPRICE=Decimal('39855.57'), L_DISCOUNT=Decimal('0.06'), L_TAX=Decimal('0.02'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1992, 11, 19), L_COMMITDATE=datetime.date(1992, 12, 3), L_RECEIPTDATE=datetime.date(1992, 11, 20), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='FOB', L_COMMENT='e along the slyly ev'),
#  Row(L_ORDERKEY=58624550, L_PARTKEY=359560, L_SUPPKEY=34570, L_LINENUMBER=5, L_QUANTITY=Decimal('37.00'), L_EXTENDEDPRICE=Decimal('59923.35'), L_DISCOUNT=Decimal('0.03'), L_TAX=Decimal('0.02'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1992, 11, 24), L_COMMITDATE=datetime.date(1992, 12, 22), L_RECEIPTDATE=datetime.date(1992, 12, 18), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='AIR', L_COMMENT='ress theod'),
#  Row(L_ORDERKEY=58624550, L_PARTKEY=1113305, L_SUPPKEY=13306, L_LINENUMBER=6, L_QUANTITY=Decimal('29.00'), L_EXTENDEDPRICE=Decimal('38229.25'), L_DISCOUNT=Decimal('0.09'), L_TAX=Decimal('0.05'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1992, 12, 10), L_COMMITDATE=datetime.date(1992, 12, 26), L_RECEIPTDATE=datetime.date(1993, 1, 2), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='REG AIR', L_COMMENT='y. ironic, bold '),
#  Row(L_ORDERKEY=58624551, L_PARTKEY=842446, L_SUPPKEY=17471, L_LINENUMBER=1, L_QUANTITY=Decimal('34.00'), L_EXTENDEDPRICE=Decimal('47205.60'), L_DISCOUNT=Decimal('0.07'), L_TAX=Decimal('0.03'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1993, 11, 17), L_COMMITDATE=datetime.date(1993, 10, 6), L_RECEIPTDATE=datetime.date(1993, 12, 4), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='MAIL', L_COMMENT='uickly bold acco'),
#  Row(L_ORDERKEY=58624551, L_PARTKEY=980793, L_SUPPKEY=30812, L_LINENUMBER=2, L_QUANTITY=Decimal('14.00'), L_EXTENDEDPRICE=Decimal('26232.50'), L_DISCOUNT=Decimal('0.09'), L_TAX=Decimal('0.02'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1993, 11, 23), L_COMMITDATE=datetime.date(1993, 10, 18), L_RECEIPTDATE=datetime.date(1993, 12, 20), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='FOB', L_COMMENT='nic platelets cajole s'),
#  Row(L_ORDERKEY=58624551, L_PARTKEY=182781, L_SUPPKEY=82782, L_LINENUMBER=3, L_QUANTITY=Decimal('18.00'), L_EXTENDEDPRICE=Decimal('33548.04'), L_DISCOUNT=Decimal('0.02'), L_TAX=Decimal('0.00'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1993, 11, 24), L_COMMITDATE=datetime.date(1993, 10, 7), L_RECEIPTDATE=datetime.date(1993, 12, 20), L_SHIPINSTRUCT='NONE', L_SHIPMODE='TRUCK', L_COMMENT='rhorses affix. final multipliers '),
#  Row(L_ORDERKEY=58624551, L_PARTKEY=1999638, L_SUPPKEY=74696, L_LINENUMBER=4, L_QUANTITY=Decimal('13.00'), L_EXTENDEDPRICE=Decimal('22588.02'), L_DISCOUNT=Decimal('0.03'), L_TAX=Decimal('0.02'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1993, 11, 9), L_COMMITDATE=datetime.date(1993, 11, 27), L_RECEIPTDATE=datetime.date(1993, 11, 27), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='MAIL', L_COMMENT='ongside of the'),
#  Row(L_ORDERKEY=58624551, L_PARTKEY=1901005, L_SUPPKEY=1006, L_LINENUMBER=5, L_QUANTITY=Decimal('5.00'), L_EXTENDEDPRICE=Decimal('5029.55'), L_DISCOUNT=Decimal('0.02'), L_TAX=Decimal('0.04'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1993, 11, 5), L_COMMITDATE=datetime.date(1993, 10, 6), L_RECEIPTDATE=datetime.date(1993, 11, 20), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='SHIP', L_COMMENT='slyly regular'),
#  Row(L_ORDERKEY=58624576, L_PARTKEY=1455994, L_SUPPKEY=81009, L_LINENUMBER=1, L_QUANTITY=Decimal('44.00'), L_EXTENDEDPRICE=Decimal('85796.48'), L_DISCOUNT=Decimal('0.03'), L_TAX=Decimal('0.04'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 7, 25), L_COMMITDATE=datetime.date(1994, 9, 11), L_RECEIPTDATE=datetime.date(1994, 8, 22), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='TRUCK', L_COMMENT='ss the bold, final asymptotes boost '),
#  Row(L_ORDERKEY=58624576, L_PARTKEY=885092, L_SUPPKEY=85093, L_LINENUMBER=2, L_QUANTITY=Decimal('15.00'), L_EXTENDEDPRICE=Decimal('16155.75'), L_DISCOUNT=Decimal('0.01'), L_TAX=Decimal('0.01'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 9, 2), L_COMMITDATE=datetime.date(1994, 9, 11), L_RECEIPTDATE=datetime.date(1994, 9, 7), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='SHIP', L_COMMENT='ly final packages. furiousl'),
#  Row(L_ORDERKEY=58624576, L_PARTKEY=1733605, L_SUPPKEY=83640, L_LINENUMBER=3, L_QUANTITY=Decimal('22.00'), L_EXTENDEDPRICE=Decimal('36047.44'), L_DISCOUNT=Decimal('0.04'), L_TAX=Decimal('0.04'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 8, 19), L_COMMITDATE=datetime.date(1994, 9, 6), L_RECEIPTDATE=datetime.date(1994, 9, 1), L_SHIPINSTRUCT='NONE', L_SHIPMODE='AIR', L_COMMENT='ronic foxes. excuses according to'),
#  Row(L_ORDERKEY=58624576, L_PARTKEY=695120, L_SUPPKEY=45133, L_LINENUMBER=4, L_QUANTITY=Decimal('15.00'), L_EXTENDEDPRICE=Decimal('16726.35'), L_DISCOUNT=Decimal('0.09'), L_TAX=Decimal('0.03'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 9, 4), L_COMMITDATE=datetime.date(1994, 8, 11), L_RECEIPTDATE=datetime.date(1994, 9, 15), L_SHIPINSTRUCT='NONE', L_SHIPMODE='REG AIR', L_COMMENT=' accounts cajole carefully slyly regular'),
#  Row(L_ORDERKEY=58624576, L_PARTKEY=872522, L_SUPPKEY=72523, L_LINENUMBER=5, L_QUANTITY=Decimal('4.00'), L_EXTENDEDPRICE=Decimal('5977.92'), L_DISCOUNT=Decimal('0.01'), L_TAX=Decimal('0.05'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 8, 1), L_COMMITDATE=datetime.date(1994, 9, 15), L_RECEIPTDATE=datetime.date(1994, 8, 4), L_SHIPINSTRUCT='NONE', L_SHIPMODE='RAIL', L_COMMENT='kly regular waters are daringly slyly re'),
#  Row(L_ORDERKEY=58624576, L_PARTKEY=462489, L_SUPPKEY=12498, L_LINENUMBER=6, L_QUANTITY=Decimal('9.00'), L_EXTENDEDPRICE=Decimal('13063.14'), L_DISCOUNT=Decimal('0.05'), L_TAX=Decimal('0.01'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 8, 13), L_COMMITDATE=datetime.date(1994, 9, 6), L_RECEIPTDATE=datetime.date(1994, 9, 4), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='REG AIR', L_COMMENT='ifts. fluffi'),
#  Row(L_ORDERKEY=58624576, L_PARTKEY=1042509, L_SUPPKEY=67520, L_LINENUMBER=7, L_QUANTITY=Decimal('50.00'), L_EXTENDEDPRICE=Decimal('72572.50'), L_DISCOUNT=Decimal('0.01'), L_TAX=Decimal('0.08'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 10, 15), L_COMMITDATE=datetime.date(1994, 9, 20), L_RECEIPTDATE=datetime.date(1994, 10, 16), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='MAIL', L_COMMENT='ajole fina'),
#  Row(L_ORDERKEY=58624577, L_PARTKEY=1433038, L_SUPPKEY=33039, L_LINENUMBER=1, L_QUANTITY=Decimal('32.00'), L_EXTENDEDPRICE=Decimal('31070.72'), L_DISCOUNT=Decimal('0.08'), L_TAX=Decimal('0.00'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1998, 7, 26), L_COMMITDATE=datetime.date(1998, 5, 13), L_RECEIPTDATE=datetime.date(1998, 8, 20), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='AIR', L_COMMENT='to beans. unusual, special excuses '),
#  Row(L_ORDERKEY=58624577, L_PARTKEY=1054244, L_SUPPKEY=54245, L_LINENUMBER=2, L_QUANTITY=Decimal('13.00'), L_EXTENDEDPRICE=Decimal('15576.47'), L_DISCOUNT=Decimal('0.10'), L_TAX=Decimal('0.08'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1998, 5, 13), L_COMMITDATE=datetime.date(1998, 6, 13), L_RECEIPTDATE=datetime.date(1998, 6, 1), L_SHIPINSTRUCT='NONE', L_SHIPMODE='RAIL', L_COMMENT='sts. even, regular accounts'),
#  Row(L_ORDERKEY=58624577, L_PARTKEY=677359, L_SUPPKEY=27372, L_LINENUMBER=3, L_QUANTITY=Decimal('22.00'), L_EXTENDEDPRICE=Decimal('29399.04'), L_DISCOUNT=Decimal('0.06'), L_TAX=Decimal('0.01'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1998, 7, 1), L_COMMITDATE=datetime.date(1998, 6, 28), L_RECEIPTDATE=datetime.date(1998, 7, 16), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='SHIP', L_COMMENT='ly unusual packages'),
#  Row(L_ORDERKEY=58624577, L_PARTKEY=369132, L_SUPPKEY=94136, L_LINENUMBER=4, L_QUANTITY=Decimal('2.00'), L_EXTENDEDPRICE=Decimal('2402.24'), L_DISCOUNT=Decimal('0.03'), L_TAX=Decimal('0.05'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1998, 4, 26), L_COMMITDATE=datetime.date(1998, 5, 21), L_RECEIPTDATE=datetime.date(1998, 5, 13), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='RAIL', L_COMMENT='gle quickl'),
#  Row(L_ORDERKEY=58624578, L_PARTKEY=895864, L_SUPPKEY=45881, L_LINENUMBER=1, L_QUANTITY=Decimal('20.00'), L_EXTENDEDPRICE=Decimal('37196.40'), L_DISCOUNT=Decimal('0.02'), L_TAX=Decimal('0.08'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 11, 7), L_COMMITDATE=datetime.date(1994, 9, 29), L_RECEIPTDATE=datetime.date(1994, 11, 26), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='SHIP', L_COMMENT='ress accounts are above the care'),
#  Row(L_ORDERKEY=58624578, L_PARTKEY=784355, L_SUPPKEY=9363, L_LINENUMBER=2, L_QUANTITY=Decimal('9.00'), L_EXTENDEDPRICE=Decimal('12953.88'), L_DISCOUNT=Decimal('0.04'), L_TAX=Decimal('0.03'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 12, 23), L_COMMITDATE=datetime.date(1994, 10, 26), L_RECEIPTDATE=datetime.date(1995, 1, 16), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='REG AIR', L_COMMENT='ly bold theod'),
#  Row(L_ORDERKEY=58624578, L_PARTKEY=646409, L_SUPPKEY=96422, L_LINENUMBER=3, L_QUANTITY=Decimal('30.00'), L_EXTENDEDPRICE=Decimal('40661.10'), L_DISCOUNT=Decimal('0.02'), L_TAX=Decimal('0.02'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 11, 24), L_COMMITDATE=datetime.date(1994, 10, 13), L_RECEIPTDATE=datetime.date(1994, 12, 22), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='TRUCK', L_COMMENT='ost after the blithely unusua'),
#  Row(L_ORDERKEY=58624578, L_PARTKEY=189937, L_SUPPKEY=14939, L_LINENUMBER=4, L_QUANTITY=Decimal('13.00'), L_EXTENDEDPRICE=Decimal('26350.09'), L_DISCOUNT=Decimal('0.03'), L_TAX=Decimal('0.01'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 11, 22), L_COMMITDATE=datetime.date(1994, 10, 12), L_RECEIPTDATE=datetime.date(1994, 12, 12), L_SHIPINSTRUCT='NONE', L_SHIPMODE='MAIL', L_COMMENT=' regular deposits. even accoun'),
#  Row(L_ORDERKEY=58624579, L_PARTKEY=296230, L_SUPPKEY=21233, L_LINENUMBER=1, L_QUANTITY=Decimal('9.00'), L_EXTENDEDPRICE=Decimal('11035.98'), L_DISCOUNT=Decimal('0.03'), L_TAX=Decimal('0.02'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1992, 2, 17), L_COMMITDATE=datetime.date(1992, 2, 29), L_RECEIPTDATE=datetime.date(1992, 3, 6), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='REG AIR', L_COMMENT='iously pending courts'),
#  Row(L_ORDERKEY=58624579, L_PARTKEY=726773, L_SUPPKEY=1795, L_LINENUMBER=2, L_QUANTITY=Decimal('42.00'), L_EXTENDEDPRICE=Decimal('75589.08'), L_DISCOUNT=Decimal('0.03'), L_TAX=Decimal('0.05'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1992, 3, 30), L_COMMITDATE=datetime.date(1992, 3, 14), L_RECEIPTDATE=datetime.date(1992, 4, 29), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='AIR', L_COMMENT='s boost carefully-- platelets wake caref'),
#  Row(L_ORDERKEY=58624579, L_PARTKEY=864212, L_SUPPKEY=64213, L_LINENUMBER=3, L_QUANTITY=Decimal('39.00'), L_EXTENDEDPRICE=Decimal('45870.63'), L_DISCOUNT=Decimal('0.02'), L_TAX=Decimal('0.00'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1992, 3, 16), L_COMMITDATE=datetime.date(1992, 4, 13), L_RECEIPTDATE=datetime.date(1992, 3, 30), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='AIR', L_COMMENT=' are quietly fluffily fin'),
#  Row(L_ORDERKEY=58624580, L_PARTKEY=214050, L_SUPPKEY=39053, L_LINENUMBER=1, L_QUANTITY=Decimal('25.00'), L_EXTENDEDPRICE=Decimal('24101.00'), L_DISCOUNT=Decimal('0.08'), L_TAX=Decimal('0.01'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1992, 12, 30), L_COMMITDATE=datetime.date(1993, 1, 10), L_RECEIPTDATE=datetime.date(1993, 1, 20), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='FOB', L_COMMENT='en grouches'),
#  Row(L_ORDERKEY=58624581, L_PARTKEY=457902, L_SUPPKEY=32915, L_LINENUMBER=1, L_QUANTITY=Decimal('21.00'), L_EXTENDEDPRICE=Decimal('39057.48'), L_DISCOUNT=Decimal('0.03'), L_TAX=Decimal('0.08'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1996, 5, 10), L_COMMITDATE=datetime.date(1996, 3, 12), L_RECEIPTDATE=datetime.date(1996, 5, 20), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='RAIL', L_COMMENT='ts sleep slyly. furiously blithe theod'),
#  Row(L_ORDERKEY=58624581, L_PARTKEY=1957968, L_SUPPKEY=57969, L_LINENUMBER=2, L_QUANTITY=Decimal('7.00'), L_EXTENDEDPRICE=Decimal('14181.09'), L_DISCOUNT=Decimal('0.07'), L_TAX=Decimal('0.04'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1996, 3, 30), L_COMMITDATE=datetime.date(1996, 4, 3), L_RECEIPTDATE=datetime.date(1996, 4, 2), L_SHIPINSTRUCT='NONE', L_SHIPMODE='RAIL', L_COMMENT='theodolites. evenly bold requests cajole'),
#  Row(L_ORDERKEY=58624581, L_PARTKEY=1560919, L_SUPPKEY=85935, L_LINENUMBER=3, L_QUANTITY=Decimal('10.00'), L_EXTENDEDPRICE=Decimal('19798.40'), L_DISCOUNT=Decimal('0.07'), L_TAX=Decimal('0.00'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1996, 2, 26), L_COMMITDATE=datetime.date(1996, 4, 5), L_RECEIPTDATE=datetime.date(1996, 2, 28), L_SHIPINSTRUCT='NONE', L_SHIPMODE='MAIL', L_COMMENT='arefully final ideas detect slyly packages'),
#  Row(L_ORDERKEY=58624581, L_PARTKEY=352557, L_SUPPKEY=77561, L_LINENUMBER=4, L_QUANTITY=Decimal('2.00'), L_EXTENDEDPRICE=Decimal('3219.08'), L_DISCOUNT=Decimal('0.00'), L_TAX=Decimal('0.08'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1996, 1, 26), L_COMMITDATE=datetime.date(1996, 3, 26), L_RECEIPTDATE=datetime.date(1996, 2, 9), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='AIR', L_COMMENT='s. unusual'),
#  Row(L_ORDERKEY=58624581, L_PARTKEY=1421601, L_SUPPKEY=71630, L_LINENUMBER=5, L_QUANTITY=Decimal('38.00'), L_EXTENDEDPRICE=Decimal('57856.14'), L_DISCOUNT=Decimal('0.04'), L_TAX=Decimal('0.07'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1996, 2, 18), L_COMMITDATE=datetime.date(1996, 3, 30), L_RECEIPTDATE=datetime.date(1996, 2, 24), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='MAIL', L_COMMENT=' impress regular'),
#  Row(L_ORDERKEY=58624581, L_PARTKEY=838068, L_SUPPKEY=13093, L_LINENUMBER=6, L_QUANTITY=Decimal('27.00'), L_EXTENDEDPRICE=Decimal('27162.54'), L_DISCOUNT=Decimal('0.06'), L_TAX=Decimal('0.05'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1996, 5, 11), L_COMMITDATE=datetime.date(1996, 3, 14), L_RECEIPTDATE=datetime.date(1996, 5, 28), L_SHIPINSTRUCT='NONE', L_SHIPMODE='REG AIR', L_COMMENT=' pinto beans. bold, even packages '),
#  Row(L_ORDERKEY=58624581, L_PARTKEY=1392918, L_SUPPKEY=67958, L_LINENUMBER=7, L_QUANTITY=Decimal('12.00'), L_EXTENDEDPRICE=Decimal('24130.20'), L_DISCOUNT=Decimal('0.02'), L_TAX=Decimal('0.03'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1996, 5, 16), L_COMMITDATE=datetime.date(1996, 4, 24), L_RECEIPTDATE=datetime.date(1996, 5, 17), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='AIR', L_COMMENT='ng the carefully unu'),
#  Row(L_ORDERKEY=58624582, L_PARTKEY=763649, L_SUPPKEY=88657, L_LINENUMBER=1, L_QUANTITY=Decimal('37.00'), L_EXTENDEDPRICE=Decimal('63366.57'), L_DISCOUNT=Decimal('0.07'), L_TAX=Decimal('0.01'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1995, 1, 12), L_COMMITDATE=datetime.date(1994, 12, 11), L_RECEIPTDATE=datetime.date(1995, 2, 9), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='FOB', L_COMMENT='ending acco'),
# ...
#  Row(L_ORDERKEY=58625440, L_PARTKEY=1529176, L_SUPPKEY=54192, L_LINENUMBER=1, L_QUANTITY=Decimal('16.00'), L_EXTENDEDPRICE=Decimal('19281.60'), L_DISCOUNT=Decimal('0.03'), L_TAX=Decimal('0.05'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 8, 7), L_COMMITDATE=datetime.date(1997, 9, 18), L_RECEIPTDATE=datetime.date(1997, 8, 12), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='TRUCK', L_COMMENT=' quickly even dependencies run '),
#  Row(L_ORDERKEY=58625440, L_PARTKEY=853931, L_SUPPKEY=78940, L_LINENUMBER=2, L_QUANTITY=Decimal('13.00'), L_EXTENDEDPRICE=Decimal('24503.57'), L_DISCOUNT=Decimal('0.02'), L_TAX=Decimal('0.06'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 10, 9), L_COMMITDATE=datetime.date(1997, 9, 24), L_RECEIPTDATE=datetime.date(1997, 10, 15), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='AIR', L_COMMENT='ins haggle quickly ar'),
#  Row(L_ORDERKEY=58625440, L_PARTKEY=9425, L_SUPPKEY=9426, L_LINENUMBER=3, L_QUANTITY=Decimal('39.00'), L_EXTENDEDPRICE=Decimal('52042.38'), L_DISCOUNT=Decimal('0.01'), L_TAX=Decimal('0.05'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 8, 31), L_COMMITDATE=datetime.date(1997, 9, 30), L_RECEIPTDATE=datetime.date(1997, 9, 28), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='AIR', L_COMMENT='e instructions sublate sil'),
#  Row(L_ORDERKEY=58625440, L_PARTKEY=405010, L_SUPPKEY=5011, L_LINENUMBER=4, L_QUANTITY=Decimal('11.00'), L_EXTENDEDPRICE=Decimal('10064.89'), L_DISCOUNT=Decimal('0.05'), L_TAX=Decimal('0.04'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 8, 24), L_COMMITDATE=datetime.date(1997, 9, 9), L_RECEIPTDATE=datetime.date(1997, 9, 5), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='RAIL', L_COMMENT='le. express accounts sleep fluffily bold re'),
#  Row(L_ORDERKEY=58625440, L_PARTKEY=993617, L_SUPPKEY=68645, L_LINENUMBER=5, L_QUANTITY=Decimal('5.00'), L_EXTENDEDPRICE=Decimal('8552.85'), L_DISCOUNT=Decimal('0.06'), L_TAX=Decimal('0.00'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 8, 13), L_COMMITDATE=datetime.date(1997, 9, 27), L_RECEIPTDATE=datetime.date(1997, 9, 6), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='MAIL', L_COMMENT='y brave accounts cajole fluffily '),
#  Row(L_ORDERKEY=58625440, L_PARTKEY=1716749, L_SUPPKEY=66784, L_LINENUMBER=6, L_QUANTITY=Decimal('12.00'), L_EXTENDEDPRICE=Decimal('21187.92'), L_DISCOUNT=Decimal('0.05'), L_TAX=Decimal('0.08'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 11, 5), L_COMMITDATE=datetime.date(1997, 10, 15), L_RECEIPTDATE=datetime.date(1997, 11, 26), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='RAIL', L_COMMENT='to the regular dep'),
#  Row(L_ORDERKEY=58625440, L_PARTKEY=1391619, L_SUPPKEY=41646, L_LINENUMBER=7, L_QUANTITY=Decimal('36.00'), L_EXTENDEDPRICE=Decimal('61579.80'), L_DISCOUNT=Decimal('0.08'), L_TAX=Decimal('0.06'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 10, 16), L_COMMITDATE=datetime.date(1997, 9, 22), L_RECEIPTDATE=datetime.date(1997, 10, 21), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='SHIP', L_COMMENT='ironic accou'),
#  Row(L_ORDERKEY=58625441, L_PARTKEY=936171, L_SUPPKEY=61181, L_LINENUMBER=1, L_QUANTITY=Decimal('47.00'), L_EXTENDEDPRICE=Decimal('56735.11'), L_DISCOUNT=Decimal('0.00'), L_TAX=Decimal('0.05'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1992, 9, 21), L_COMMITDATE=datetime.date(1992, 11, 19), L_RECEIPTDATE=datetime.date(1992, 10, 14), L_SHIPINSTRUCT='NONE', L_SHIPMODE='REG AIR', L_COMMENT=' packages are'),
#  Row(L_ORDERKEY=58625442, L_PARTKEY=623182, L_SUPPKEY=48189, L_LINENUMBER=1, L_QUANTITY=Decimal('11.00'), L_EXTENDEDPRICE=Decimal('12156.65'), L_DISCOUNT=Decimal('0.00'), L_TAX=Decimal('0.07'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 10, 10), L_COMMITDATE=datetime.date(1994, 10, 17), L_RECEIPTDATE=datetime.date(1994, 10, 23), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='TRUCK', L_COMMENT='ress packages poach '),
#  Row(L_ORDERKEY=58625442, L_PARTKEY=1818434, L_SUPPKEY=93489, L_LINENUMBER=2, L_QUANTITY=Decimal('9.00'), L_EXTENDEDPRICE=Decimal('12171.06'), L_DISCOUNT=Decimal('0.02'), L_TAX=Decimal('0.01'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 12, 5), L_COMMITDATE=datetime.date(1994, 10, 11), L_RECEIPTDATE=datetime.date(1994, 12, 30), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='MAIL', L_COMMENT='iously regular mult'),
#  Row(L_ORDERKEY=58625442, L_PARTKEY=405586, L_SUPPKEY=55595, L_LINENUMBER=3, L_QUANTITY=Decimal('24.00'), L_EXTENDEDPRICE=Decimal('35797.44'), L_DISCOUNT=Decimal('0.04'), L_TAX=Decimal('0.06'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 12, 17), L_COMMITDATE=datetime.date(1994, 11, 3), L_RECEIPTDATE=datetime.date(1994, 12, 18), L_SHIPINSTRUCT='NONE', L_SHIPMODE='AIR', L_COMMENT='uickly. requests engage careful'),
#  Row(L_ORDERKEY=58625442, L_PARTKEY=681755, L_SUPPKEY=81756, L_LINENUMBER=4, L_QUANTITY=Decimal('15.00'), L_EXTENDEDPRICE=Decimal('26050.80'), L_DISCOUNT=Decimal('0.02'), L_TAX=Decimal('0.03'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 10, 3), L_COMMITDATE=datetime.date(1994, 11, 16), L_RECEIPTDATE=datetime.date(1994, 10, 11), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='TRUCK', L_COMMENT='arhorses. carefull'),
#  Row(L_ORDERKEY=58625442, L_PARTKEY=240087, L_SUPPKEY=15094, L_LINENUMBER=5, L_QUANTITY=Decimal('35.00'), L_EXTENDEDPRICE=Decimal('35947.45'), L_DISCOUNT=Decimal('0.03'), L_TAX=Decimal('0.03'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 10, 6), L_COMMITDATE=datetime.date(1994, 10, 28), L_RECEIPTDATE=datetime.date(1994, 10, 24), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='TRUCK', L_COMMENT='eas wake. bold pac'),
#  Row(L_ORDERKEY=58625443, L_PARTKEY=263871, L_SUPPKEY=88874, L_LINENUMBER=1, L_QUANTITY=Decimal('6.00'), L_EXTENDEDPRICE=Decimal('11009.16'), L_DISCOUNT=Decimal('0.02'), L_TAX=Decimal('0.03'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 12, 3), L_COMMITDATE=datetime.date(1994, 12, 27), L_RECEIPTDATE=datetime.date(1994, 12, 22), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='REG AIR', L_COMMENT='posits wake blithely. fluffi'),
#  Row(L_ORDERKEY=58625444, L_PARTKEY=1034755, L_SUPPKEY=84776, L_LINENUMBER=1, L_QUANTITY=Decimal('35.00'), L_EXTENDEDPRICE=Decimal('59139.50'), L_DISCOUNT=Decimal('0.03'), L_TAX=Decimal('0.08'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1995, 1, 25), L_COMMITDATE=datetime.date(1995, 1, 25), L_RECEIPTDATE=datetime.date(1995, 2, 16), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='MAIL', L_COMMENT='y unusual acc'),
#  Row(L_ORDERKEY=58625444, L_PARTKEY=1112093, L_SUPPKEY=62116, L_LINENUMBER=2, L_QUANTITY=Decimal('24.00'), L_EXTENDEDPRICE=Decimal('26520.96'), L_DISCOUNT=Decimal('0.04'), L_TAX=Decimal('0.08'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1995, 1, 15), L_COMMITDATE=datetime.date(1995, 2, 14), L_RECEIPTDATE=datetime.date(1995, 2, 9), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='AIR', L_COMMENT='rays. dolp'),
#  Row(L_ORDERKEY=58625444, L_PARTKEY=944223, L_SUPPKEY=19251, L_LINENUMBER=3, L_QUANTITY=Decimal('37.00'), L_EXTENDEDPRICE=Decimal('46885.66'), L_DISCOUNT=Decimal('0.08'), L_TAX=Decimal('0.07'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1995, 2, 18), L_COMMITDATE=datetime.date(1995, 3, 22), L_RECEIPTDATE=datetime.date(1995, 2, 19), L_SHIPINSTRUCT='NONE', L_SHIPMODE='FOB', L_COMMENT='s since the bl'),
#  Row(L_ORDERKEY=58625445, L_PARTKEY=970994, L_SUPPKEY=96004, L_LINENUMBER=1, L_QUANTITY=Decimal('46.00'), L_EXTENDEDPRICE=Decimal('94987.70'), L_DISCOUNT=Decimal('0.02'), L_TAX=Decimal('0.05'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1995, 8, 31), L_COMMITDATE=datetime.date(1995, 7, 15), L_RECEIPTDATE=datetime.date(1995, 9, 22), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='MAIL', L_COMMENT='ithely final t'),
#  Row(L_ORDERKEY=58625445, L_PARTKEY=1485637, L_SUPPKEY=35666, L_LINENUMBER=2, L_QUANTITY=Decimal('22.00'), L_EXTENDEDPRICE=Decimal('35696.32'), L_DISCOUNT=Decimal('0.01'), L_TAX=Decimal('0.03'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1995, 8, 17), L_COMMITDATE=datetime.date(1995, 7, 29), L_RECEIPTDATE=datetime.date(1995, 8, 29), L_SHIPINSTRUCT='NONE', L_SHIPMODE='MAIL', L_COMMENT='ffily across the bli'),
#  Row(L_ORDERKEY=58625445, L_PARTKEY=1096639, L_SUPPKEY=71670, L_LINENUMBER=3, L_QUANTITY=Decimal('38.00'), L_EXTENDEDPRICE=Decimal('62152.04'), L_DISCOUNT=Decimal('0.03'), L_TAX=Decimal('0.08'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1995, 10, 5), L_COMMITDATE=datetime.date(1995, 8, 24), L_RECEIPTDATE=datetime.date(1995, 10, 26), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='MAIL', L_COMMENT='according to the iro'),
#  Row(L_ORDERKEY=58625445, L_PARTKEY=1195793, L_SUPPKEY=95794, L_LINENUMBER=4, L_QUANTITY=Decimal('9.00'), L_EXTENDEDPRICE=Decimal('16998.66'), L_DISCOUNT=Decimal('0.01'), L_TAX=Decimal('0.01'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1995, 9, 10), L_COMMITDATE=datetime.date(1995, 7, 24), L_RECEIPTDATE=datetime.date(1995, 10, 4), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='AIR', L_COMMENT='even deposits haggle quickly'),
#  Row(L_ORDERKEY=58625446, L_PARTKEY=1815007, L_SUPPKEY=15008, L_LINENUMBER=1, L_QUANTITY=Decimal('29.00'), L_EXTENDEDPRICE=Decimal('26735.39'), L_DISCOUNT=Decimal('0.03'), L_TAX=Decimal('0.05'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 7, 22), L_COMMITDATE=datetime.date(1994, 7, 12), L_RECEIPTDATE=datetime.date(1994, 8, 10), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='REG AIR', L_COMMENT='ly above the furiously speci'),
#  Row(L_ORDERKEY=58625447, L_PARTKEY=1847246, L_SUPPKEY=47247, L_LINENUMBER=1, L_QUANTITY=Decimal('6.00'), L_EXTENDEDPRICE=Decimal('7158.90'), L_DISCOUNT=Decimal('0.02'), L_TAX=Decimal('0.03'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1995, 10, 17), L_COMMITDATE=datetime.date(1995, 9, 28), L_RECEIPTDATE=datetime.date(1995, 10, 23), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='FOB', L_COMMENT='efully regular accounts. fluffily regul'),
#  Row(L_ORDERKEY=58625447, L_PARTKEY=658725, L_SUPPKEY=58726, L_LINENUMBER=2, L_QUANTITY=Decimal('30.00'), L_EXTENDEDPRICE=Decimal('50510.70'), L_DISCOUNT=Decimal('0.04'), L_TAX=Decimal('0.03'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1995, 9, 13), L_COMMITDATE=datetime.date(1995, 10, 14), L_RECEIPTDATE=datetime.date(1995, 10, 12), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='MAIL', L_COMMENT='efully. final deposits kindle alo'),
#  Row(L_ORDERKEY=58625447, L_PARTKEY=1183411, L_SUPPKEY=33434, L_LINENUMBER=3, L_QUANTITY=Decimal('50.00'), L_EXTENDEDPRICE=Decimal('74718.00'), L_DISCOUNT=Decimal('0.01'), L_TAX=Decimal('0.04'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1995, 8, 16), L_COMMITDATE=datetime.date(1995, 10, 14), L_RECEIPTDATE=datetime.date(1995, 8, 27), L_SHIPINSTRUCT='NONE', L_SHIPMODE='AIR', L_COMMENT='gular, regular accounts c'),
#  Row(L_ORDERKEY=58625447, L_PARTKEY=1573352, L_SUPPKEY=98368, L_LINENUMBER=4, L_QUANTITY=Decimal('9.00'), L_EXTENDEDPRICE=Decimal('12827.52'), L_DISCOUNT=Decimal('0.04'), L_TAX=Decimal('0.06'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1995, 11, 3), L_COMMITDATE=datetime.date(1995, 9, 1), L_RECEIPTDATE=datetime.date(1995, 11, 11), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='RAIL', L_COMMENT='kly pending ideas: final'),
#  Row(L_ORDERKEY=58625447, L_PARTKEY=1319684, L_SUPPKEY=19685, L_LINENUMBER=5, L_QUANTITY=Decimal('47.00'), L_EXTENDEDPRICE=Decimal('80070.14'), L_DISCOUNT=Decimal('0.07'), L_TAX=Decimal('0.07'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1995, 11, 17), L_COMMITDATE=datetime.date(1995, 9, 12), L_RECEIPTDATE=datetime.date(1995, 12, 6), L_SHIPINSTRUCT='NONE', L_SHIPMODE='SHIP', L_COMMENT='equests. quickly bold ideas nag fox'),
#  Row(L_ORDERKEY=58625447, L_PARTKEY=1927836, L_SUPPKEY=52856, L_LINENUMBER=6, L_QUANTITY=Decimal('33.00'), L_EXTENDEDPRICE=Decimal('61503.42'), L_DISCOUNT=Decimal('0.02'), L_TAX=Decimal('0.06'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1995, 10, 22), L_COMMITDATE=datetime.date(1995, 10, 9), L_RECEIPTDATE=datetime.date(1995, 10, 31), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='FOB', L_COMMENT='ly against the slyly expres'),
#  Row(L_ORDERKEY=58625472, L_PARTKEY=1706126, L_SUPPKEY=6127, L_LINENUMBER=1, L_QUANTITY=Decimal('37.00'), L_EXTENDEDPRICE=Decimal('41885.48'), L_DISCOUNT=Decimal('0.08'), L_TAX=Decimal('0.03'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1992, 6, 12), L_COMMITDATE=datetime.date(1992, 7, 19), L_RECEIPTDATE=datetime.date(1992, 6, 28), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='TRUCK', L_COMMENT='e. slyly regular ideas wake'),
#  Row(L_ORDERKEY=58625472, L_PARTKEY=847311, L_SUPPKEY=72320, L_LINENUMBER=2, L_QUANTITY=Decimal('48.00'), L_EXTENDEDPRICE=Decimal('60396.96'), L_DISCOUNT=Decimal('0.04'), L_TAX=Decimal('0.04'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1992, 8, 25), L_COMMITDATE=datetime.date(1992, 8, 6), L_RECEIPTDATE=datetime.date(1992, 9, 2), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='REG AIR', L_COMMENT='xes use quickly alongside o'),
#  Row(L_ORDERKEY=58625472, L_PARTKEY=750762, L_SUPPKEY=75770, L_LINENUMBER=3, L_QUANTITY=Decimal('40.00'), L_EXTENDEDPRICE=Decimal('72509.20'), L_DISCOUNT=Decimal('0.00'), L_TAX=Decimal('0.01'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1992, 7, 14), L_COMMITDATE=datetime.date(1992, 8, 1), L_RECEIPTDATE=datetime.date(1992, 8, 11), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='AIR', L_COMMENT='nal packages use carefully final packa'),
#  Row(L_ORDERKEY=58625472, L_PARTKEY=45604, L_SUPPKEY=70605, L_LINENUMBER=4, L_QUANTITY=Decimal('8.00'), L_EXTENDEDPRICE=Decimal('12396.80'), L_DISCOUNT=Decimal('0.08'), L_TAX=Decimal('0.01'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1992, 8, 1), L_COMMITDATE=datetime.date(1992, 8, 8), L_RECEIPTDATE=datetime.date(1992, 8, 23), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='TRUCK', L_COMMENT='al foxes. requests against the final p'),
#  Row(L_ORDERKEY=58625472, L_PARTKEY=450774, L_SUPPKEY=25787, L_LINENUMBER=5, L_QUANTITY=Decimal('7.00'), L_EXTENDEDPRICE=Decimal('12073.25'), L_DISCOUNT=Decimal('0.08'), L_TAX=Decimal('0.04'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1992, 8, 28), L_COMMITDATE=datetime.date(1992, 7, 26), L_RECEIPTDATE=datetime.date(1992, 9, 3), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='REG AIR', L_COMMENT='egular requests use blithely. quickly'),
#  Row(L_ORDERKEY=58625473, L_PARTKEY=1170107, L_SUPPKEY=95119, L_LINENUMBER=1, L_QUANTITY=Decimal('44.00'), L_EXTENDEDPRICE=Decimal('51790.20'), L_DISCOUNT=Decimal('0.01'), L_TAX=Decimal('0.02'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1996, 8, 8), L_COMMITDATE=datetime.date(1996, 8, 13), L_RECEIPTDATE=datetime.date(1996, 8, 21), L_SHIPINSTRUCT='NONE', L_SHIPMODE='FOB', L_COMMENT='s. daringly regular pinto beans '),
#  Row(L_ORDERKEY=58625473, L_PARTKEY=1982560, L_SUPPKEY=7580, L_LINENUMBER=2, L_QUANTITY=Decimal('42.00'), L_EXTENDEDPRICE=Decimal('68983.74'), L_DISCOUNT=Decimal('0.08'), L_TAX=Decimal('0.07'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1996, 8, 4), L_COMMITDATE=datetime.date(1996, 7, 18), L_RECEIPTDATE=datetime.date(1996, 8, 18), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='MAIL', L_COMMENT='quickly even d'),
#  Row(L_ORDERKEY=58625474, L_PARTKEY=1626413, L_SUPPKEY=1462, L_LINENUMBER=1, L_QUANTITY=Decimal('10.00'), L_EXTENDEDPRICE=Decimal('13393.30'), L_DISCOUNT=Decimal('0.09'), L_TAX=Decimal('0.03'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 10, 23), L_COMMITDATE=datetime.date(1997, 10, 24), L_RECEIPTDATE=datetime.date(1997, 11, 3), L_SHIPINSTRUCT='NONE', L_SHIPMODE='REG AIR', L_COMMENT='ven accounts a')]

# %%
for row in df.collect():
    print(f"{row.L_ORDERKEY}: {row.L_EXTENDEDPRICE}")
# Out:
# 58624485: 22322.58
# 58624486: 54706.75
# 58624486: 38772.96
# 58624486: 3036.90
# 58624486: 55745.04
# 58624486: 45517.23
# 58624487: 83193.30
# 58624512: 53415.20
# 58624513: 47999.16
# 58624513: 42964.37
# 58624513: 22180.80
# 58624513: 50627.70
# 58624514: 13072.50
# 58624514: 2752.64
# 58624514: 81955.44
# 58624514: 28902.93
# 58624514: 86332.42
# 58624515: 11829.42
# 58624515: 43164.80
# 58624515: 11126.22
# 58624515: 7907.70
# 58624515: 87794.28
# 58624515: 62112.14
# 58624516: 55572.86
# 58624516: 5911.25
# 58624516: 41841.58
# 58624516: 52944.12
# 58624517: 40425.18
# 58624517: 36349.02
# 58624517: 40647.60
# 58624517: 74366.67
# 58624517: 17643.00
# 58624517: 73529.24
# 58624517: 24565.60
# 58624518: 63172.72
# 58624518: 62524.58
# 58624518: 44205.20
# 58624518: 34814.30
# 58624518: 51492.40
# 58624519: 24411.14
# 58624519: 19104.14
# 58624519: 15998.95
# 58624519: 10981.62
# 58624519: 1809.69
# 58624519: 6888.49
# 58624544: 21125.12
# 58624544: 21624.47
# 58624544: 39451.88
# 58624544: 29759.40
# 58625410: 74823.00
# 58625410: 1290.28
# 58625410: 50132.32
# 58625410: 2910.66
# 58625410: 88793.28
# 58625411: 77226.00
# 58625411: 80664.13
# 58625411: 77193.98
# 58625412: 30291.36
# 58625412: 32792.20
# 58625412: 57813.24
# 58625412: 80286.24
# 58625412: 13693.20
# 58625413: 9673.44
# 58625413: 59708.00
# 58625413: 29844.48
# 58625413: 48447.98
# 58625414: 69928.37
# 58625414: 9837.38
# 58625415: 16367.25
# 58625415: 35757.62
# 58625415: 37611.84
# 58625415: 13381.04
# 58625415: 7026.60
# 58625415: 40918.23
# 58625440: 19281.60
# 58625440: 24503.57
# 58625440: 52042.38
# 58625440: 10064.89
# 58625440: 8552.85
# 58625440: 21187.92
# 58625440: 61579.80
# 58625441: 56735.11
# 58625442: 12156.65
# 58625442: 12171.06
# 58625442: 35797.44
# 58625442: 26050.80
# 58625442: 35947.45
# 58625443: 11009.16
# 58625444: 59139.50
# 58625444: 26520.96
# 58625444: 46885.66
# 58625445: 94987.70
# 58625445: 35696.32
# 58625445: 62152.04
# 58625445: 16998.66
# 58625446: 26735.39
# 58625447: 7158.90
# 58625447: 50510.70
# 58625447: 74718.00
# 58625447: 12827.52
# 58625447: 80070.14
# 58625447: 61503.42
# 58625472: 41885.48
# 58625472: 60396.96
# 58625472: 72509.20
# 58625472: 12396.80
# 58625472: 12073.25
# 58625473: 51790.20
# 58625473: 68983.74
# 58625474: 13393.30

# %% [markdown]
# ### Set Database and Schema for Session

# %%
sp_session.use_database("snowflake_sample_data")

sp_session.use_schema("tpch_sf10")

# %% [markdown]
# ### Set Table for Session

# %%
sp_session.table("lineitem")

# %% [markdown]
# ### Select from Dataframe and Filter

# %%
from_date = datetime.date(1997, 1, 1)
to_date = datetime.date(1997, 12, 31)

df = df.select(
    "L_SHIPDATE",
    "L_EXTENDEDPRICE",
    "L_SHIPMODE",
    "L_QUANTITY",
    "L_DISCOUNT",
).filter(
    functions.col("L_SHIPDATE").between(from_date, to_date)
)

# %%
df.show()
# Out:
# ---------------------------------------------------------------------------------
# |"L_SHIPDATE"  |"L_EXTENDEDPRICE"  |"L_SHIPMODE"  |"L_QUANTITY"  |"L_DISCOUNT"  |
# ---------------------------------------------------------------------------------
# |1997-01-05    |35034.44           |TRUCK         |28.00         |0.09          |
# |1997-03-03    |53808.81           |TRUCK         |33.00         |0.06          |
# |1997-03-24    |53854.40           |SHIP          |40.00         |0.07          |
# |1997-04-04    |51264.00           |SHIP          |45.00         |0.05          |
# |1997-02-18    |66305.28           |REG AIR       |48.00         |0.04          |
# |1997-03-27    |19925.46           |TRUCK         |18.00         |0.07          |
# |1997-11-16    |2200.36            |RAIL          |2.00          |0.04          |
# |1997-09-14    |18963.90           |TRUCK         |15.00         |0.10          |
# |1997-08-29    |1266.35            |FOB           |1.00          |0.06          |
# |1997-09-27    |7835.88            |AIR           |4.00          |0.04          |
# ---------------------------------------------------------------------------------

# %% [markdown]
# ### Create New Columns

# %%
df = df.with_column("REVENUE",
