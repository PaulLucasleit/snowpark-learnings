# %%
# Add module folder to notebook
import os
import sys

from dotenv import find_dotenv
sys.path.append(os.path.dirname(find_dotenv()))

# %%
from snowflake.snowpark import functions
import datetime

from app.snowpark_session.session import snowpark_session

# %%
sp_session = snowpark_session()

# %% [markdown]
# ### Run SQL Commands

# %%
sql = """
select *
from snowflake_sample_data.tpch_sf10.lineitem
limit 1000
"""

df = sp_session.sql(sql)

# %% [markdown]
# ### Show dataframe

# %%
df.show()
# Out:
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |"L_ORDERKEY"  |"L_PARTKEY"  |"L_SUPPKEY"  |"L_LINENUMBER"  |"L_QUANTITY"  |"L_EXTENDEDPRICE"  |"L_DISCOUNT"  |"L_TAX"  |"L_RETURNFLAG"  |"L_LINESTATUS"  |"L_SHIPDATE"  |"L_COMMITDATE"  |"L_RECEIPTDATE"  |"L_SHIPINSTRUCT"   |"L_SHIPMODE"  |"L_COMMENT"                                 |
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |51426183      |929063       |4091         |5               |12.00         |13104.24           |0.05          |0.02     |N               |O               |1996-04-21    |1996-06-26      |1996-05-17       |TAKE BACK RETURN   |AIR           |dencies are f                               |
# |51426183      |747366       |22388        |6               |4.00          |5653.32            |0.10          |0.00     |N               |O               |1996-07-04    |1996-05-25      |1996-07-11       |COLLECT COD        |MAIL          |its haggle carefully. depos                 |
# |51426208      |1254802      |79815        |1               |23.00         |40405.02           |0.10          |0.02     |A               |F               |1993-09-26    |1993-09-06      |1993-10-24       |NONE               |REG AIR       |quests. silent, ir                          |
# |51426208      |1444010      |19053        |2               |43.00         |41019.42           |0.01          |0.07     |R               |F               |1993-08-13    |1993-08-04      |1993-08-25       |TAKE BACK RETURN   |MAIL          |l, express ideas. fluffily special pa       |
# |51426208      |1462131      |62132        |3               |32.00         |34977.92           |0.00          |0.07     |A               |F               |1993-09-27    |1993-09-09      |1993-10-21       |DELIVER IN PERSON  |SHIP          |unusual platelets sleep careful             |
# |51426208      |25948        |25949        |4               |42.00         |78705.48           |0.03          |0.02     |A               |F               |1993-08-07    |1993-09-22      |1993-08-10       |TAKE BACK RETURN   |RAIL          |e furiously                                 |
# |51426208      |100714       |715          |5               |35.00         |60014.85           |0.04          |0.07     |A               |F               |1993-09-29    |1993-08-04      |1993-10-11       |DELIVER IN PERSON  |FOB           |efully final de                             |
# |51426208      |684780       |34793        |6               |7.00          |12353.25           |0.06          |0.04     |R               |F               |1993-07-25    |1993-08-30      |1993-08-17       |DELIVER IN PERSON  |AIR           |y alongside of the slyly final platelets.   |
# |51426208      |1095192      |45213        |7               |2.00          |2374.28            |0.09          |0.07     |A               |F               |1993-08-15    |1993-08-06      |1993-09-03       |TAKE BACK RETURN   |FOB           |eodolites according to the furiously re     |
# |51426209      |891535       |91536        |1               |3.00          |4579.47            |0.08          |0.06     |R               |F               |1995-05-08    |1995-03-10      |1995-05-25       |TAKE BACK RETURN   |RAIL          |y. final, final pinto b                     |
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
df.collect()
# Out:
# [Row(L_ORDERKEY=51426183, L_PARTKEY=929063, L_SUPPKEY=4091, L_LINENUMBER=5, L_QUANTITY=Decimal('12.00'), L_EXTENDEDPRICE=Decimal('13104.24'), L_DISCOUNT=Decimal('0.05'), L_TAX=Decimal('0.02'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1996, 4, 21), L_COMMITDATE=datetime.date(1996, 6, 26), L_RECEIPTDATE=datetime.date(1996, 5, 17), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='AIR', L_COMMENT='dencies are f'),
#  Row(L_ORDERKEY=51426183, L_PARTKEY=747366, L_SUPPKEY=22388, L_LINENUMBER=6, L_QUANTITY=Decimal('4.00'), L_EXTENDEDPRICE=Decimal('5653.32'), L_DISCOUNT=Decimal('0.10'), L_TAX=Decimal('0.00'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1996, 7, 4), L_COMMITDATE=datetime.date(1996, 5, 25), L_RECEIPTDATE=datetime.date(1996, 7, 11), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='MAIL', L_COMMENT='its haggle carefully. depos'),
#  Row(L_ORDERKEY=51426208, L_PARTKEY=1254802, L_SUPPKEY=79815, L_LINENUMBER=1, L_QUANTITY=Decimal('23.00'), L_EXTENDEDPRICE=Decimal('40405.02'), L_DISCOUNT=Decimal('0.10'), L_TAX=Decimal('0.02'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1993, 9, 26), L_COMMITDATE=datetime.date(1993, 9, 6), L_RECEIPTDATE=datetime.date(1993, 10, 24), L_SHIPINSTRUCT='NONE', L_SHIPMODE='REG AIR', L_COMMENT='quests. silent, ir'),
#  Row(L_ORDERKEY=51426208, L_PARTKEY=1444010, L_SUPPKEY=19053, L_LINENUMBER=2, L_QUANTITY=Decimal('43.00'), L_EXTENDEDPRICE=Decimal('41019.42'), L_DISCOUNT=Decimal('0.01'), L_TAX=Decimal('0.07'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1993, 8, 13), L_COMMITDATE=datetime.date(1993, 8, 4), L_RECEIPTDATE=datetime.date(1993, 8, 25), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='MAIL', L_COMMENT='l, express ideas. fluffily special pa'),
#  Row(L_ORDERKEY=51426208, L_PARTKEY=1462131, L_SUPPKEY=62132, L_LINENUMBER=3, L_QUANTITY=Decimal('32.00'), L_EXTENDEDPRICE=Decimal('34977.92'), L_DISCOUNT=Decimal('0.00'), L_TAX=Decimal('0.07'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1993, 9, 27), L_COMMITDATE=datetime.date(1993, 9, 9), L_RECEIPTDATE=datetime.date(1993, 10, 21), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='SHIP', L_COMMENT='unusual platelets sleep careful'),
#  Row(L_ORDERKEY=51426208, L_PARTKEY=25948, L_SUPPKEY=25949, L_LINENUMBER=4, L_QUANTITY=Decimal('42.00'), L_EXTENDEDPRICE=Decimal('78705.48'), L_DISCOUNT=Decimal('0.03'), L_TAX=Decimal('0.02'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1993, 8, 7), L_COMMITDATE=datetime.date(1993, 9, 22), L_RECEIPTDATE=datetime.date(1993, 8, 10), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='RAIL', L_COMMENT='e furiously '),
#  Row(L_ORDERKEY=51426208, L_PARTKEY=100714, L_SUPPKEY=715, L_LINENUMBER=5, L_QUANTITY=Decimal('35.00'), L_EXTENDEDPRICE=Decimal('60014.85'), L_DISCOUNT=Decimal('0.04'), L_TAX=Decimal('0.07'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1993, 9, 29), L_COMMITDATE=datetime.date(1993, 8, 4), L_RECEIPTDATE=datetime.date(1993, 10, 11), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='FOB', L_COMMENT='efully final de'),
#  Row(L_ORDERKEY=51426208, L_PARTKEY=684780, L_SUPPKEY=34793, L_LINENUMBER=6, L_QUANTITY=Decimal('7.00'), L_EXTENDEDPRICE=Decimal('12353.25'), L_DISCOUNT=Decimal('0.06'), L_TAX=Decimal('0.04'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1993, 7, 25), L_COMMITDATE=datetime.date(1993, 8, 30), L_RECEIPTDATE=datetime.date(1993, 8, 17), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='AIR', L_COMMENT='y alongside of the slyly final platelets. '),
#  Row(L_ORDERKEY=51426208, L_PARTKEY=1095192, L_SUPPKEY=45213, L_LINENUMBER=7, L_QUANTITY=Decimal('2.00'), L_EXTENDEDPRICE=Decimal('2374.28'), L_DISCOUNT=Decimal('0.09'), L_TAX=Decimal('0.07'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1993, 8, 15), L_COMMITDATE=datetime.date(1993, 8, 6), L_RECEIPTDATE=datetime.date(1993, 9, 3), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='FOB', L_COMMENT='eodolites according to the furiously re'),
#  Row(L_ORDERKEY=51426209, L_PARTKEY=891535, L_SUPPKEY=91536, L_LINENUMBER=1, L_QUANTITY=Decimal('3.00'), L_EXTENDEDPRICE=Decimal('4579.47'), L_DISCOUNT=Decimal('0.08'), L_TAX=Decimal('0.06'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1995, 5, 8), L_COMMITDATE=datetime.date(1995, 3, 10), L_RECEIPTDATE=datetime.date(1995, 5, 25), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='RAIL', L_COMMENT='y. final, final pinto b'),
#  Row(L_ORDERKEY=51426210, L_PARTKEY=1256828, L_SUPPKEY=81841, L_LINENUMBER=1, L_QUANTITY=Decimal('46.00'), L_EXTENDEDPRICE=Decimal('82098.96'), L_DISCOUNT=Decimal('0.06'), L_TAX=Decimal('0.04'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1995, 2, 24), L_COMMITDATE=datetime.date(1995, 4, 22), L_RECEIPTDATE=datetime.date(1995, 3, 25), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='AIR', L_COMMENT=' even braids above the final ins'),
#  Row(L_ORDERKEY=51426210, L_PARTKEY=1501880, L_SUPPKEY=26896, L_LINENUMBER=2, L_QUANTITY=Decimal('33.00'), L_EXTENDEDPRICE=Decimal('62099.73'), L_DISCOUNT=Decimal('0.02'), L_TAX=Decimal('0.02'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1995, 3, 22), L_COMMITDATE=datetime.date(1995, 5, 5), L_RECEIPTDATE=datetime.date(1995, 4, 12), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='AIR', L_COMMENT='refully at'),
#  Row(L_ORDERKEY=51426210, L_PARTKEY=87113, L_SUPPKEY=87114, L_LINENUMBER=3, L_QUANTITY=Decimal('42.00'), L_EXTENDEDPRICE=Decimal('46204.62'), L_DISCOUNT=Decimal('0.01'), L_TAX=Decimal('0.00'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1995, 3, 4), L_COMMITDATE=datetime.date(1995, 4, 20), L_RECEIPTDATE=datetime.date(1995, 3, 8), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='AIR', L_COMMENT='s wake blithely. quickly regular asymptot'),
#  Row(L_ORDERKEY=51426211, L_PARTKEY=101112, L_SUPPKEY=26114, L_LINENUMBER=1, L_QUANTITY=Decimal('5.00'), L_EXTENDEDPRICE=Decimal('5565.55'), L_DISCOUNT=Decimal('0.01'), L_TAX=Decimal('0.06'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 7, 3), L_COMMITDATE=datetime.date(1997, 7, 22), L_RECEIPTDATE=datetime.date(1997, 7, 23), L_SHIPINSTRUCT='NONE', L_SHIPMODE='SHIP', L_COMMENT=' pending fo'),
#  Row(L_ORDERKEY=51426211, L_PARTKEY=1388895, L_SUPPKEY=38922, L_LINENUMBER=2, L_QUANTITY=Decimal('19.00'), L_EXTENDEDPRICE=Decimal('37692.77'), L_DISCOUNT=Decimal('0.04'), L_TAX=Decimal('0.02'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 5, 19), L_COMMITDATE=datetime.date(1997, 7, 6), L_RECEIPTDATE=datetime.date(1997, 6, 6), L_SHIPINSTRUCT='NONE', L_SHIPMODE='RAIL', L_COMMENT='counts. slyly regular d'),
#  Row(L_ORDERKEY=51426211, L_PARTKEY=1153743, L_SUPPKEY=78755, L_LINENUMBER=3, L_QUANTITY=Decimal('4.00'), L_EXTENDEDPRICE=Decimal('7186.76'), L_DISCOUNT=Decimal('0.09'), L_TAX=Decimal('0.00'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 8, 10), L_COMMITDATE=datetime.date(1997, 7, 26), L_RECEIPTDATE=datetime.date(1997, 8, 16), L_SHIPINSTRUCT='NONE', L_SHIPMODE='RAIL', L_COMMENT='the carefully final accounts. '),
#  Row(L_ORDERKEY=51426211, L_PARTKEY=944159, L_SUPPKEY=44160, L_LINENUMBER=4, L_QUANTITY=Decimal('32.00'), L_EXTENDEDPRICE=Decimal('38499.52'), L_DISCOUNT=Decimal('0.00'), L_TAX=Decimal('0.04'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 7, 11), L_COMMITDATE=datetime.date(1997, 8, 15), L_RECEIPTDATE=datetime.date(1997, 8, 1), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='FOB', L_COMMENT='lar requests. final, express deposits ab'),
#  Row(L_ORDERKEY=51426211, L_PARTKEY=474971, L_SUPPKEY=99976, L_LINENUMBER=5, L_QUANTITY=Decimal('47.00'), L_EXTENDEDPRICE=Decimal('91459.65'), L_DISCOUNT=Decimal('0.07'), L_TAX=Decimal('0.07'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 6, 11), L_COMMITDATE=datetime.date(1997, 8, 6), L_RECEIPTDATE=datetime.date(1997, 6, 29), L_SHIPINSTRUCT='NONE', L_SHIPMODE='REG AIR', L_COMMENT='fter the ironic deposits slee'),
#  Row(L_ORDERKEY=51426211, L_PARTKEY=823969, L_SUPPKEY=98994, L_LINENUMBER=6, L_QUANTITY=Decimal('32.00'), L_EXTENDEDPRICE=Decimal('60573.44'), L_DISCOUNT=Decimal('0.10'), L_TAX=Decimal('0.00'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 7, 29), L_COMMITDATE=datetime.date(1997, 6, 26), L_RECEIPTDATE=datetime.date(1997, 8, 21), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='AIR', L_COMMENT='dependencies cajole express decoys-'),
#  Row(L_ORDERKEY=51426211, L_PARTKEY=446129, L_SUPPKEY=71134, L_LINENUMBER=7, L_QUANTITY=Decimal('5.00'), L_EXTENDEDPRICE=Decimal('5375.50'), L_DISCOUNT=Decimal('0.01'), L_TAX=Decimal('0.02'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 5, 20), L_COMMITDATE=datetime.date(1997, 7, 26), L_RECEIPTDATE=datetime.date(1997, 6, 7), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='FOB', L_COMMENT='ecial, pending packages at t'),
#  Row(L_ORDERKEY=51426212, L_PARTKEY=87912, L_SUPPKEY=37913, L_LINENUMBER=1, L_QUANTITY=Decimal('41.00'), L_EXTENDEDPRICE=Decimal('77896.31'), L_DISCOUNT=Decimal('0.04'), L_TAX=Decimal('0.03'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 6, 4), L_COMMITDATE=datetime.date(1997, 5, 19), L_RECEIPTDATE=datetime.date(1997, 6, 25), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='SHIP', L_COMMENT=' slyly ironic platelets. blithely'),
#  Row(L_ORDERKEY=51426213, L_PARTKEY=301413, L_SUPPKEY=26417, L_LINENUMBER=1, L_QUANTITY=Decimal('23.00'), L_EXTENDEDPRICE=Decimal('32531.20'), L_DISCOUNT=Decimal('0.06'), L_TAX=Decimal('0.08'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 3, 23), L_COMMITDATE=datetime.date(1994, 5, 20), L_RECEIPTDATE=datetime.date(1994, 4, 13), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='TRUCK', L_COMMENT='ffily express pinto beans across the fluff'),
#  Row(L_ORDERKEY=51426214, L_PARTKEY=1465607, L_SUPPKEY=40650, L_LINENUMBER=1, L_QUANTITY=Decimal('37.00'), L_EXTENDEDPRICE=Decimal('58183.61'), L_DISCOUNT=Decimal('0.10'), L_TAX=Decimal('0.06'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1995, 7, 23), L_COMMITDATE=datetime.date(1995, 6, 11), L_RECEIPTDATE=datetime.date(1995, 8, 12), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='REG AIR', L_COMMENT='uickly regular, pending requests. ruthless'),
#  Row(L_ORDERKEY=51426214, L_PARTKEY=450014, L_SUPPKEY=25027, L_LINENUMBER=2, L_QUANTITY=Decimal('31.00'), L_EXTENDEDPRICE=Decimal('29883.69'), L_DISCOUNT=Decimal('0.05'), L_TAX=Decimal('0.00'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1995, 6, 8), L_COMMITDATE=datetime.date(1995, 5, 18), L_RECEIPTDATE=datetime.date(1995, 6, 16), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='SHIP', L_COMMENT='ests run caref'),
#  Row(L_ORDERKEY=51426214, L_PARTKEY=1372260, L_SUPPKEY=22287, L_LINENUMBER=3, L_QUANTITY=Decimal('5.00'), L_EXTENDEDPRICE=Decimal('6661.00'), L_DISCOUNT=Decimal('0.04'), L_TAX=Decimal('0.05'), L_RETURNFLAG='N', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1995, 6, 1), L_COMMITDATE=datetime.date(1995, 7, 2), L_RECEIPTDATE=datetime.date(1995, 7, 1), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='REG AIR', L_COMMENT='egular, ironic pinto beans. blithe'),
#  Row(L_ORDERKEY=51426214, L_PARTKEY=1571915, L_SUPPKEY=21946, L_LINENUMBER=4, L_QUANTITY=Decimal('29.00'), L_EXTENDEDPRICE=Decimal('57618.36'), L_DISCOUNT=Decimal('0.02'), L_TAX=Decimal('0.02'), L_RETURNFLAG='N', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1995, 6, 17), L_COMMITDATE=datetime.date(1995, 6, 17), L_RECEIPTDATE=datetime.date(1995, 7, 15), L_SHIPINSTRUCT='NONE', L_SHIPMODE='AIR', L_COMMENT='s. slyly even '),
#  Row(L_ORDERKEY=51426215, L_PARTKEY=589089, L_SUPPKEY=64105, L_LINENUMBER=1, L_QUANTITY=Decimal('49.00'), L_EXTENDEDPRICE=Decimal('57724.94'), L_DISCOUNT=Decimal('0.02'), L_TAX=Decimal('0.05'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1995, 12, 22), L_COMMITDATE=datetime.date(1995, 12, 11), L_RECEIPTDATE=datetime.date(1996, 1, 12), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='TRUCK', L_COMMENT='l pearls snooze doggedly. slyly spec'),
#  Row(L_ORDERKEY=51426215, L_PARTKEY=813000, L_SUPPKEY=38009, L_LINENUMBER=2, L_QUANTITY=Decimal('8.00'), L_EXTENDEDPRICE=Decimal('7303.68'), L_DISCOUNT=Decimal('0.06'), L_TAX=Decimal('0.00'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1996, 2, 8), L_COMMITDATE=datetime.date(1995, 11, 25), L_RECEIPTDATE=datetime.date(1996, 3, 7), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='TRUCK', L_COMMENT='the pending deposits. furiously express re'),
#  Row(L_ORDERKEY=51426215, L_PARTKEY=77265, L_SUPPKEY=52266, L_LINENUMBER=3, L_QUANTITY=Decimal('16.00'), L_EXTENDEDPRICE=Decimal('19876.16'), L_DISCOUNT=Decimal('0.00'), L_TAX=Decimal('0.08'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1995, 12, 25), L_COMMITDATE=datetime.date(1996, 1, 3), L_RECEIPTDATE=datetime.date(1996, 1, 5), L_SHIPINSTRUCT='NONE', L_SHIPMODE='TRUCK', L_COMMENT='er the exp'),
#  Row(L_ORDERKEY=51426215, L_PARTKEY=586735, L_SUPPKEY=11741, L_LINENUMBER=4, L_QUANTITY=Decimal('26.00'), L_EXTENDEDPRICE=Decimal('47364.46'), L_DISCOUNT=Decimal('0.03'), L_TAX=Decimal('0.02'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1996, 2, 2), L_COMMITDATE=datetime.date(1995, 11, 28), L_RECEIPTDATE=datetime.date(1996, 3, 3), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='SHIP', L_COMMENT='ously final packages along the'),
#  Row(L_ORDERKEY=51426240, L_PARTKEY=1860220, L_SUPPKEY=35275, L_LINENUMBER=1, L_QUANTITY=Decimal('26.00'), L_EXTENDEDPRICE=Decimal('30683.38'), L_DISCOUNT=Decimal('0.02'), L_TAX=Decimal('0.08'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1992, 9, 21), L_COMMITDATE=datetime.date(1992, 11, 20), L_RECEIPTDATE=datetime.date(1992, 9, 29), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='RAIL', L_COMMENT=' use thinly. quickly even '),
#  Row(L_ORDERKEY=51426240, L_PARTKEY=708182, L_SUPPKEY=8183, L_LINENUMBER=2, L_QUANTITY=Decimal('45.00'), L_EXTENDEDPRICE=Decimal('53556.75'), L_DISCOUNT=Decimal('0.06'), L_TAX=Decimal('0.01'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1992, 12, 19), L_COMMITDATE=datetime.date(1992, 10, 20), L_RECEIPTDATE=datetime.date(1992, 12, 24), L_SHIPINSTRUCT='NONE', L_SHIPMODE='FOB', L_COMMENT='ounts would cajole sl'),
#  Row(L_ORDERKEY=51426240, L_PARTKEY=398955, L_SUPPKEY=73965, L_LINENUMBER=3, L_QUANTITY=Decimal('34.00'), L_EXTENDEDPRICE=Decimal('69833.96'), L_DISCOUNT=Decimal('0.03'), L_TAX=Decimal('0.08'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1992, 11, 15), L_COMMITDATE=datetime.date(1992, 11, 18), L_RECEIPTDATE=datetime.date(1992, 12, 14), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='FOB', L_COMMENT='egular foxes use blithely. '),
#  Row(L_ORDERKEY=51426240, L_PARTKEY=1226336, L_SUPPKEY=51349, L_LINENUMBER=4, L_QUANTITY=Decimal('50.00'), L_EXTENDEDPRICE=Decimal('63113.50'), L_DISCOUNT=Decimal('0.05'), L_TAX=Decimal('0.01'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1992, 12, 31), L_COMMITDATE=datetime.date(1992, 11, 9), L_RECEIPTDATE=datetime.date(1993, 1, 3), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='RAIL', L_COMMENT='ironic deposits. sl'),
#  Row(L_ORDERKEY=51426240, L_PARTKEY=1020687, L_SUPPKEY=45698, L_LINENUMBER=5, L_QUANTITY=Decimal('29.00'), L_EXTENDEDPRICE=Decimal('46621.27'), L_DISCOUNT=Decimal('0.07'), L_TAX=Decimal('0.06'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1992, 10, 21), L_COMMITDATE=datetime.date(1992, 11, 17), L_RECEIPTDATE=datetime.date(1992, 10, 23), L_SHIPINSTRUCT='NONE', L_SHIPMODE='RAIL', L_COMMENT='iously final ideas d'),
#  Row(L_ORDERKEY=51426240, L_PARTKEY=669636, L_SUPPKEY=69637, L_LINENUMBER=6, L_QUANTITY=Decimal('18.00'), L_EXTENDEDPRICE=Decimal('28900.80'), L_DISCOUNT=Decimal('0.05'), L_TAX=Decimal('0.00'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1992, 12, 29), L_COMMITDATE=datetime.date(1992, 10, 27), L_RECEIPTDATE=datetime.date(1993, 1, 5), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='REG AIR', L_COMMENT=' final packages. requests integrate s'),
#  Row(L_ORDERKEY=51426241, L_PARTKEY=1642677, L_SUPPKEY=42678, L_LINENUMBER=1, L_QUANTITY=Decimal('15.00'), L_EXTENDEDPRICE=Decimal('24293.85'), L_DISCOUNT=Decimal('0.04'), L_TAX=Decimal('0.05'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1995, 2, 18), L_COMMITDATE=datetime.date(1995, 2, 5), L_RECEIPTDATE=datetime.date(1995, 2, 28), L_SHIPINSTRUCT='NONE', L_SHIPMODE='TRUCK', L_COMMENT='posits thrash along the quickly '),
#  Row(L_ORDERKEY=51426241, L_PARTKEY=471566, L_SUPPKEY=71567, L_LINENUMBER=2, L_QUANTITY=Decimal('41.00'), L_EXTENDEDPRICE=Decimal('63039.14'), L_DISCOUNT=Decimal('0.10'), L_TAX=Decimal('0.02'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1995, 3, 26), L_COMMITDATE=datetime.date(1995, 2, 11), L_RECEIPTDATE=datetime.date(1995, 4, 7), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='TRUCK', L_COMMENT='heodolites '),
#  Row(L_ORDERKEY=51426241, L_PARTKEY=1605243, L_SUPPKEY=80292, L_LINENUMBER=3, L_QUANTITY=Decimal('14.00'), L_EXTENDEDPRICE=Decimal('16074.24'), L_DISCOUNT=Decimal('0.05'), L_TAX=Decimal('0.07'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1995, 2, 14), L_COMMITDATE=datetime.date(1995, 2, 25), L_RECEIPTDATE=datetime.date(1995, 3, 8), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='AIR', L_COMMENT='nto beans wake furiously'),
#  Row(L_ORDERKEY=51426242, L_PARTKEY=247138, L_SUPPKEY=47139, L_LINENUMBER=1, L_QUANTITY=Decimal('44.00'), L_EXTENDEDPRICE=Decimal('47745.28'), L_DISCOUNT=Decimal('0.00'), L_TAX=Decimal('0.03'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 7, 3), L_COMMITDATE=datetime.date(1997, 5, 6), L_RECEIPTDATE=datetime.date(1997, 7, 19), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='AIR', L_COMMENT='e slyly. quickly unusual theodolites hagg'),
#  Row(L_ORDERKEY=51426242, L_PARTKEY=1646523, L_SUPPKEY=71540, L_LINENUMBER=2, L_QUANTITY=Decimal('26.00'), L_EXTENDEDPRICE=Decimal('38205.44'), L_DISCOUNT=Decimal('0.05'), L_TAX=Decimal('0.04'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 7, 1), L_COMMITDATE=datetime.date(1997, 4, 24), L_RECEIPTDATE=datetime.date(1997, 7, 25), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='RAIL', L_COMMENT=', special requests haggle. quickly fin'),
#  Row(L_ORDERKEY=51426242, L_PARTKEY=1103336, L_SUPPKEY=53359, L_LINENUMBER=3, L_QUANTITY=Decimal('16.00'), L_EXTENDEDPRICE=Decimal('21428.48'), L_DISCOUNT=Decimal('0.02'), L_TAX=Decimal('0.02'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 5, 9), L_COMMITDATE=datetime.date(1997, 4, 29), L_RECEIPTDATE=datetime.date(1997, 6, 7), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='AIR', L_COMMENT='e of the slyly bold tithes. final requests '),
#  Row(L_ORDERKEY=51426242, L_PARTKEY=1756514, L_SUPPKEY=6549, L_LINENUMBER=4, L_QUANTITY=Decimal('28.00'), L_EXTENDEDPRICE=Decimal('43972.04'), L_DISCOUNT=Decimal('0.03'), L_TAX=Decimal('0.04'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 5, 20), L_COMMITDATE=datetime.date(1997, 4, 30), L_RECEIPTDATE=datetime.date(1997, 6, 8), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='SHIP', L_COMMENT='regular pinto beans. furiously final th'),
#  Row(L_ORDERKEY=51426242, L_PARTKEY=1714717, L_SUPPKEY=89769, L_LINENUMBER=5, L_QUANTITY=Decimal('20.00'), L_EXTENDEDPRICE=Decimal('34632.60'), L_DISCOUNT=Decimal('0.04'), L_TAX=Decimal('0.05'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 5, 30), L_COMMITDATE=datetime.date(1997, 4, 10), L_RECEIPTDATE=datetime.date(1997, 6, 3), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='FOB', L_COMMENT=' even foxes. r'),
#  Row(L_ORDERKEY=51426242, L_PARTKEY=1247800, L_SUPPKEY=47801, L_LINENUMBER=6, L_QUANTITY=Decimal('30.00'), L_EXTENDEDPRICE=Decimal('52432.20'), L_DISCOUNT=Decimal('0.02'), L_TAX=Decimal('0.08'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 4, 11), L_COMMITDATE=datetime.date(1997, 4, 22), L_RECEIPTDATE=datetime.date(1997, 4, 23), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='MAIL', L_COMMENT=' furiously expres'),
#  Row(L_ORDERKEY=51426242, L_PARTKEY=1763200, L_SUPPKEY=38252, L_LINENUMBER=7, L_QUANTITY=Decimal('33.00'), L_EXTENDEDPRICE=Decimal('41682.96'), L_DISCOUNT=Decimal('0.06'), L_TAX=Decimal('0.05'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 5, 14), L_COMMITDATE=datetime.date(1997, 5, 23), L_RECEIPTDATE=datetime.date(1997, 6, 10), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='AIR', L_COMMENT='iously after the even pains. regular, regul'),
#  Row(L_ORDERKEY=51426243, L_PARTKEY=87606, L_SUPPKEY=62607, L_LINENUMBER=1, L_QUANTITY=Decimal('46.00'), L_EXTENDEDPRICE=Decimal('73305.60'), L_DISCOUNT=Decimal('0.01'), L_TAX=Decimal('0.07'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 7, 10), L_COMMITDATE=datetime.date(1994, 6, 22), L_RECEIPTDATE=datetime.date(1994, 8, 6), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='REG AIR', L_COMMENT='its. packages boost slyly. bravely unusual'),
#  Row(L_ORDERKEY=51426243, L_PARTKEY=379029, L_SUPPKEY=54039, L_LINENUMBER=2, L_QUANTITY=Decimal('27.00'), L_EXTENDEDPRICE=Decimal('29916.27'), L_DISCOUNT=Decimal('0.00'), L_TAX=Decimal('0.01'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 4, 25), L_COMMITDATE=datetime.date(1994, 7, 13), L_RECEIPTDATE=datetime.date(1994, 5, 6), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='SHIP', L_COMMENT='its cajole slyly pending courts. c'),
#  Row(L_ORDERKEY=51426243, L_PARTKEY=324553, L_SUPPKEY=24554, L_LINENUMBER=3, L_QUANTITY=Decimal('38.00'), L_EXTENDEDPRICE=Decimal('59946.52'), L_DISCOUNT=Decimal('0.03'), L_TAX=Decimal('0.05'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 4, 27), L_COMMITDATE=datetime.date(1994, 5, 28), L_RECEIPTDATE=datetime.date(1994, 5, 24), L_SHIPINSTRUCT='NONE', L_SHIPMODE='REG AIR', L_COMMENT='le slyly unusual theodolites. silent, b'),
#  Row(L_ORDERKEY=51426243, L_PARTKEY=757794, L_SUPPKEY=57795, L_LINENUMBER=4, L_QUANTITY=Decimal('46.00'), L_EXTENDEDPRICE=Decimal('85180.96'), L_DISCOUNT=Decimal('0.01'), L_TAX=Decimal('0.07'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 7, 24), L_COMMITDATE=datetime.date(1994, 6, 29), L_RECEIPTDATE=datetime.date(1994, 7, 27), L_SHIPINSTRUCT='NONE', L_SHIPMODE='SHIP', L_COMMENT='. quickly unusual foxes after the'),
#  Row(L_ORDERKEY=51426243, L_PARTKEY=237929, L_SUPPKEY=37930, L_LINENUMBER=5, L_QUANTITY=Decimal('12.00'), L_EXTENDEDPRICE=Decimal('22402.92'), L_DISCOUNT=Decimal('0.04'), L_TAX=Decimal('0.00'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 5, 2), L_COMMITDATE=datetime.date(1994, 6, 30), L_RECEIPTDATE=datetime.date(1994, 5, 4), L_SHIPINSTRUCT='NONE', L_SHIPMODE='SHIP', L_COMMENT='sly regular deposits haggle slyly along'),
#  Row(L_ORDERKEY=51426243, L_PARTKEY=872057, L_SUPPKEY=47082, L_LINENUMBER=6, L_QUANTITY=Decimal('6.00'), L_EXTENDEDPRICE=Decimal('6174.06'), L_DISCOUNT=Decimal('0.06'), L_TAX=Decimal('0.07'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 6, 29), L_COMMITDATE=datetime.date(1994, 6, 13), L_RECEIPTDATE=datetime.date(1994, 7, 6), L_SHIPINSTRUCT='NONE', L_SHIPMODE='MAIL', L_COMMENT='ts integrate blithely brav'),
#  Row(L_ORDERKEY=51426243, L_PARTKEY=648110, L_SUPPKEY=73117, L_LINENUMBER=7, L_QUANTITY=Decimal('8.00'), L_EXTENDEDPRICE=Decimal('8464.64'), L_DISCOUNT=Decimal('0.03'), L_TAX=Decimal('0.00'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 5, 2), L_COMMITDATE=datetime.date(1994, 7, 5), L_RECEIPTDATE=datetime.date(1994, 5, 27), L_SHIPINSTRUCT='NONE', L_SHIPMODE='FOB', L_COMMENT='. special, final ideas according to t'),
#  Row(L_ORDERKEY=51426244, L_PARTKEY=770257, L_SUPPKEY=95265, L_LINENUMBER=1, L_QUANTITY=Decimal('4.00'), L_EXTENDEDPRICE=Decimal('5308.88'), L_DISCOUNT=Decimal('0.03'), L_TAX=Decimal('0.07'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1992, 12, 19), L_COMMITDATE=datetime.date(1992, 12, 17), L_RECEIPTDATE=datetime.date(1992, 12, 24), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='TRUCK', L_COMMENT='kages. regular pinto beans against the '),
#  Row(L_ORDERKEY=51426244, L_PARTKEY=1698196, L_SUPPKEY=48229, L_LINENUMBER=2, L_QUANTITY=Decimal('19.00'), L_EXTENDEDPRICE=Decimal('22688.09'), L_DISCOUNT=Decimal('0.04'), L_TAX=Decimal('0.04'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1992, 11, 8), L_COMMITDATE=datetime.date(1992, 12, 3), L_RECEIPTDATE=datetime.date(1992, 11, 11), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='SHIP', L_COMMENT='nal attainments. slyly regula'),
#  Row(L_ORDERKEY=51426244, L_PARTKEY=1574323, L_SUPPKEY=99339, L_LINENUMBER=3, L_QUANTITY=Decimal('45.00'), L_EXTENDEDPRICE=Decimal('62876.25'), L_DISCOUNT=Decimal('0.01'), L_TAX=Decimal('0.06'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1992, 12, 17), L_COMMITDATE=datetime.date(1992, 12, 4), L_RECEIPTDATE=datetime.date(1992, 12, 18), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='TRUCK', L_COMMENT='g furiously. regular'),
#  Row(L_ORDERKEY=51426244, L_PARTKEY=1639355, L_SUPPKEY=39356, L_LINENUMBER=4, L_QUANTITY=Decimal('44.00'), L_EXTENDEDPRICE=Decimal('56947.88'), L_DISCOUNT=Decimal('0.07'), L_TAX=Decimal('0.04'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1992, 11, 12), L_COMMITDATE=datetime.date(1992, 11, 6), L_RECEIPTDATE=datetime.date(1992, 12, 9), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='SHIP', L_COMMENT='the requests nag idl'),
#  Row(L_ORDERKEY=51426244, L_PARTKEY=628277, L_SUPPKEY=78290, L_LINENUMBER=5, L_QUANTITY=Decimal('23.00'), L_EXTENDEDPRICE=Decimal('27720.52'), L_DISCOUNT=Decimal('0.00'), L_TAX=Decimal('0.00'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1992, 10, 25), L_COMMITDATE=datetime.date(1992, 12, 27), L_RECEIPTDATE=datetime.date(1992, 11, 7), L_SHIPINSTRUCT='NONE', L_SHIPMODE='RAIL', L_COMMENT='thely. regular requests do a'),
#  Row(L_ORDERKEY=51426244, L_PARTKEY=1445487, L_SUPPKEY=20530, L_LINENUMBER=6, L_QUANTITY=Decimal('24.00'), L_EXTENDEDPRICE=Decimal('34377.84'), L_DISCOUNT=Decimal('0.04'), L_TAX=Decimal('0.02'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1992, 11, 10), L_COMMITDATE=datetime.date(1992, 11, 3), L_RECEIPTDATE=datetime.date(1992, 11, 12), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='TRUCK', L_COMMENT=' foxes. slyly unusual grouches haggle car'),
#  Row(L_ORDERKEY=51426245, L_PARTKEY=1615039, L_SUPPKEY=90088, L_LINENUMBER=1, L_QUANTITY=Decimal('1.00'), L_EXTENDEDPRICE=Decimal('953.95'), L_DISCOUNT=Decimal('0.02'), L_TAX=Decimal('0.04'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1992, 12, 31), L_COMMITDATE=datetime.date(1992, 12, 3), L_RECEIPTDATE=datetime.date(1993, 1, 5), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='MAIL', L_COMMENT='ess accounts ca'),
#  Row(L_ORDERKEY=51426245, L_PARTKEY=1949440, L_SUPPKEY=74460, L_LINENUMBER=2, L_QUANTITY=Decimal('6.00'), L_EXTENDEDPRICE=Decimal('8936.10'), L_DISCOUNT=Decimal('0.08'), L_TAX=Decimal('0.03'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1992, 12, 29), L_COMMITDATE=datetime.date(1992, 11, 2), L_RECEIPTDATE=datetime.date(1993, 1, 14), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='AIR', L_COMMENT='haggle slyly above the blithely exp'),
#  Row(L_ORDERKEY=51426245, L_PARTKEY=232048, L_SUPPKEY=7055, L_LINENUMBER=3, L_QUANTITY=Decimal('37.00'), L_EXTENDEDPRICE=Decimal('36261.11'), L_DISCOUNT=Decimal('0.06'), L_TAX=Decimal('0.02'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1992, 12, 14), L_COMMITDATE=datetime.date(1992, 11, 1), L_RECEIPTDATE=datetime.date(1993, 1, 1), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='TRUCK', L_COMMENT='s affix around t'),
#  Row(L_ORDERKEY=51426245, L_PARTKEY=20223, L_SUPPKEY=45224, L_LINENUMBER=4, L_QUANTITY=Decimal('18.00'), L_EXTENDEDPRICE=Decimal('20577.96'), L_DISCOUNT=Decimal('0.09'), L_TAX=Decimal('0.03'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1992, 12, 9), L_COMMITDATE=datetime.date(1992, 12, 7), L_RECEIPTDATE=datetime.date(1992, 12, 10), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='TRUCK', L_COMMENT='e of the bold dolphins. quietly bold reque'),
#  Row(L_ORDERKEY=51426246, L_PARTKEY=1312258, L_SUPPKEY=62285, L_LINENUMBER=1, L_QUANTITY=Decimal('36.00'), L_EXTENDEDPRICE=Decimal('45726.84'), L_DISCOUNT=Decimal('0.08'), L_TAX=Decimal('0.07'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1993, 3, 16), L_COMMITDATE=datetime.date(1993, 5, 2), L_RECEIPTDATE=datetime.date(1993, 4, 10), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='RAIL', L_COMMENT=' the blithely regular i'),
#  Row(L_ORDERKEY=51426247, L_PARTKEY=1570010, L_SUPPKEY=45056, L_LINENUMBER=1, L_QUANTITY=Decimal('14.00'), L_EXTENDEDPRICE=Decimal('15119.16'), L_DISCOUNT=Decimal('0.10'), L_TAX=Decimal('0.02'), L_RETURNFLAG='N', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1995, 6, 3), L_COMMITDATE=datetime.date(1995, 4, 3), L_RECEIPTDATE=datetime.date(1995, 6, 28), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='SHIP', L_COMMENT='ckly about the sometimes even dependencies'),
#  Row(L_ORDERKEY=51426272, L_PARTKEY=14770, L_SUPPKEY=39771, L_LINENUMBER=1, L_QUANTITY=Decimal('18.00'), L_EXTENDEDPRICE=Decimal('30325.86'), L_DISCOUNT=Decimal('0.05'), L_TAX=Decimal('0.02'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 4, 8), L_COMMITDATE=datetime.date(1994, 1, 28), L_RECEIPTDATE=datetime.date(1994, 5, 2), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='FOB', L_COMMENT='oost ironic instructions. careful'),
#  Row(L_ORDERKEY=51426272, L_PARTKEY=238925, L_SUPPKEY=13932, L_LINENUMBER=2, L_QUANTITY=Decimal('30.00'), L_EXTENDEDPRICE=Decimal('55917.30'), L_DISCOUNT=Decimal('0.03'), L_TAX=Decimal('0.05'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 3, 30), L_COMMITDATE=datetime.date(1994, 3, 15), L_RECEIPTDATE=datetime.date(1994, 4, 16), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='REG AIR', L_COMMENT=' ironic pinto beans haggle. quickly r'),
#  Row(L_ORDERKEY=51426273, L_PARTKEY=27316, L_SUPPKEY=52317, L_LINENUMBER=1, L_QUANTITY=Decimal('28.00'), L_EXTENDEDPRICE=Decimal('34812.68'), L_DISCOUNT=Decimal('0.05'), L_TAX=Decimal('0.03'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 10, 22), L_COMMITDATE=datetime.date(1994, 8, 28), L_RECEIPTDATE=datetime.date(1994, 11, 11), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='RAIL', L_COMMENT='ickly thin, unusual foxes! ideas '),
#  Row(L_ORDERKEY=51426273, L_PARTKEY=1098562, L_SUPPKEY=98563, L_LINENUMBER=2, L_QUANTITY=Decimal('16.00'), L_EXTENDEDPRICE=Decimal('24968.16'), L_DISCOUNT=Decimal('0.04'), L_TAX=Decimal('0.07'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 10, 14), L_COMMITDATE=datetime.date(1994, 8, 27), L_RECEIPTDATE=datetime.date(1994, 11, 8), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='AIR', L_COMMENT='aggle across the packages!'),
#  Row(L_ORDERKEY=51426273, L_PARTKEY=1527541, L_SUPPKEY=27542, L_LINENUMBER=3, L_QUANTITY=Decimal('49.00'), L_EXTENDEDPRICE=Decimal('76855.03'), L_DISCOUNT=Decimal('0.08'), L_TAX=Decimal('0.05'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 8, 30), L_COMMITDATE=datetime.date(1994, 9, 17), L_RECEIPTDATE=datetime.date(1994, 9, 27), L_SHIPINSTRUCT='NONE', L_SHIPMODE='AIR', L_COMMENT='e ironic a'),
#  Row(L_ORDERKEY=51426273, L_PARTKEY=1379305, L_SUPPKEY=54345, L_LINENUMBER=4, L_QUANTITY=Decimal('44.00'), L_EXTENDEDPRICE=Decimal('60906.56'), L_DISCOUNT=Decimal('0.08'), L_TAX=Decimal('0.04'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 10, 2), L_COMMITDATE=datetime.date(1994, 9, 9), L_RECEIPTDATE=datetime.date(1994, 10, 21), L_SHIPINSTRUCT='NONE', L_SHIPMODE='RAIL', L_COMMENT='deas above t'),
#  Row(L_ORDERKEY=51426273, L_PARTKEY=1973393, L_SUPPKEY=73394, L_LINENUMBER=5, L_QUANTITY=Decimal('28.00'), L_EXTENDEDPRICE=Decimal('41056.40'), L_DISCOUNT=Decimal('0.05'), L_TAX=Decimal('0.06'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 8, 4), L_COMMITDATE=datetime.date(1994, 10, 17), L_RECEIPTDATE=datetime.date(1994, 8, 23), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='AIR', L_COMMENT='odolites wake always regular, r'),
#  Row(L_ORDERKEY=51426273, L_PARTKEY=809338, L_SUPPKEY=9339, L_LINENUMBER=6, L_QUANTITY=Decimal('6.00'), L_EXTENDEDPRICE=Decimal('7483.74'), L_DISCOUNT=Decimal('0.06'), L_TAX=Decimal('0.02'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 10, 1), L_COMMITDATE=datetime.date(1994, 10, 8), L_RECEIPTDATE=datetime.date(1994, 10, 31), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='RAIL', L_COMMENT=' slyly even packages snoo'),
#  Row(L_ORDERKEY=51426274, L_PARTKEY=1674469, L_SUPPKEY=24502, L_LINENUMBER=1, L_QUANTITY=Decimal('40.00'), L_EXTENDEDPRICE=Decimal('57735.20'), L_DISCOUNT=Decimal('0.01'), L_TAX=Decimal('0.03'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1998, 8, 17), L_COMMITDATE=datetime.date(1998, 6, 21), L_RECEIPTDATE=datetime.date(1998, 8, 20), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='MAIL', L_COMMENT='dle forges. regular theo'),
#  Row(L_ORDERKEY=51426274, L_PARTKEY=788831, L_SUPPKEY=38846, L_LINENUMBER=2, L_QUANTITY=Decimal('15.00'), L_EXTENDEDPRICE=Decimal('28797.00'), L_DISCOUNT=Decimal('0.08'), L_TAX=Decimal('0.00'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1998, 6, 20), L_COMMITDATE=datetime.date(1998, 7, 8), L_RECEIPTDATE=datetime.date(1998, 7, 19), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='FOB', L_COMMENT='nt requests are blithely a'),
#  Row(L_ORDERKEY=51426275, L_PARTKEY=529010, L_SUPPKEY=79021, L_LINENUMBER=1, L_QUANTITY=Decimal('3.00'), L_EXTENDEDPRICE=Decimal('3116.97'), L_DISCOUNT=Decimal('0.10'), L_TAX=Decimal('0.00'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 1, 16), L_COMMITDATE=datetime.date(1997, 2, 16), L_RECEIPTDATE=datetime.date(1997, 2, 4), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='SHIP', L_COMMENT=' the blithely final a'),
#  Row(L_ORDERKEY=51426275, L_PARTKEY=1066374, L_SUPPKEY=91385, L_LINENUMBER=2, L_QUANTITY=Decimal('8.00'), L_EXTENDEDPRICE=Decimal('10722.56'), L_DISCOUNT=Decimal('0.00'), L_TAX=Decimal('0.03'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 3, 17), L_COMMITDATE=datetime.date(1997, 3, 16), L_RECEIPTDATE=datetime.date(1997, 3, 24), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='AIR', L_COMMENT='iously silent excuses.'),
#  Row(L_ORDERKEY=51426275, L_PARTKEY=537734, L_SUPPKEY=12750, L_LINENUMBER=3, L_QUANTITY=Decimal('30.00'), L_EXTENDEDPRICE=Decimal('53151.30'), L_DISCOUNT=Decimal('0.00'), L_TAX=Decimal('0.06'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 4, 15), L_COMMITDATE=datetime.date(1997, 3, 1), L_RECEIPTDATE=datetime.date(1997, 5, 15), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='TRUCK', L_COMMENT='ely unusual ideas against the blithely'),
#  Row(L_ORDERKEY=51426275, L_PARTKEY=1679377, L_SUPPKEY=79378, L_LINENUMBER=4, L_QUANTITY=Decimal('33.00'), L_EXTENDEDPRICE=Decimal('44757.57'), L_DISCOUNT=Decimal('0.08'), L_TAX=Decimal('0.08'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 3, 14), L_COMMITDATE=datetime.date(1997, 3, 31), L_RECEIPTDATE=datetime.date(1997, 4, 6), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='TRUCK', L_COMMENT='nal deposits cajole blithely. q'),
#  Row(L_ORDERKEY=51426275, L_PARTKEY=1282879, L_SUPPKEY=7892, L_LINENUMBER=5, L_QUANTITY=Decimal('13.00'), L_EXTENDEDPRICE=Decimal('24203.53'), L_DISCOUNT=Decimal('0.10'), L_TAX=Decimal('0.01'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 5, 9), L_COMMITDATE=datetime.date(1997, 2, 27), L_RECEIPTDATE=datetime.date(1997, 5, 20), L_SHIPINSTRUCT='NONE', L_SHIPMODE='REG AIR', L_COMMENT=' by the slowly idle dep'),
#  Row(L_ORDERKEY=51426275, L_PARTKEY=1345964, L_SUPPKEY=70978, L_LINENUMBER=6, L_QUANTITY=Decimal('2.00'), L_EXTENDEDPRICE=Decimal('4019.80'), L_DISCOUNT=Decimal('0.00'), L_TAX=Decimal('0.06'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 3, 5), L_COMMITDATE=datetime.date(1997, 3, 3), L_RECEIPTDATE=datetime.date(1997, 3, 26), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='REG AIR', L_COMMENT=' accounts solve. fluffily regula'),
#  Row(L_ORDERKEY=51426275, L_PARTKEY=1603429, L_SUPPKEY=53462, L_LINENUMBER=7, L_QUANTITY=Decimal('46.00'), L_EXTENDEDPRICE=Decimal('61287.64'), L_DISCOUNT=Decimal('0.07'), L_TAX=Decimal('0.04'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 1, 29), L_COMMITDATE=datetime.date(1997, 3, 16), L_RECEIPTDATE=datetime.date(1997, 2, 18), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='FOB', L_COMMENT=' carefully final packages nag bli'),
#  Row(L_ORDERKEY=51426276, L_PARTKEY=819991, L_SUPPKEY=95016, L_LINENUMBER=1, L_QUANTITY=Decimal('5.00'), L_EXTENDEDPRICE=Decimal('9554.75'), L_DISCOUNT=Decimal('0.03'), L_TAX=Decimal('0.07'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 6, 12), L_COMMITDATE=datetime.date(1997, 5, 24), L_RECEIPTDATE=datetime.date(1997, 6, 26), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='FOB', L_COMMENT=': silent requests after the blithely specia'),
#  Row(L_ORDERKEY=51426276, L_PARTKEY=1584424, L_SUPPKEY=9440, L_LINENUMBER=2, L_QUANTITY=Decimal('47.00'), L_EXTENDEDPRICE=Decimal('70892.45'), L_DISCOUNT=Decimal('0.03'), L_TAX=Decimal('0.08'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 3, 29), L_COMMITDATE=datetime.date(1997, 6, 9), L_RECEIPTDATE=datetime.date(1997, 4, 3), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='REG AIR', L_COMMENT=' unusual packages. blit'),
#  Row(L_ORDERKEY=51426276, L_PARTKEY=1400817, L_SUPPKEY=75860, L_LINENUMBER=3, L_QUANTITY=Decimal('16.00'), L_EXTENDEDPRICE=Decimal('27483.84'), L_DISCOUNT=Decimal('0.08'), L_TAX=Decimal('0.00'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 7, 10), L_COMMITDATE=datetime.date(1997, 4, 19), L_RECEIPTDATE=datetime.date(1997, 8, 8), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='TRUCK', L_COMMENT='al accounts. fluffily furious ideas na'),
#  Row(L_ORDERKEY=51426276, L_PARTKEY=1529379, L_SUPPKEY=79410, L_LINENUMBER=4, L_QUANTITY=Decimal('38.00'), L_EXTENDEDPRICE=Decimal('53515.40'), L_DISCOUNT=Decimal('0.10'), L_TAX=Decimal('0.07'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 6, 13), L_COMMITDATE=datetime.date(1997, 6, 10), L_RECEIPTDATE=datetime.date(1997, 7, 9), L_SHIPINSTRUCT='NONE', L_SHIPMODE='FOB', L_COMMENT='ly. final, ironic deposits affix abou'),
#  Row(L_ORDERKEY=51426277, L_PARTKEY=901715, L_SUPPKEY=51734, L_LINENUMBER=1, L_QUANTITY=Decimal('40.00'), L_EXTENDEDPRICE=Decimal('68666.80'), L_DISCOUNT=Decimal('0.09'), L_TAX=Decimal('0.02'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1993, 7, 6), L_COMMITDATE=datetime.date(1993, 7, 7), L_RECEIPTDATE=datetime.date(1993, 7, 26), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='TRUCK', L_COMMENT='oxes are flu'),
#  Row(L_ORDERKEY=51426277, L_PARTKEY=1120572, L_SUPPKEY=45584, L_LINENUMBER=2, L_QUANTITY=Decimal('47.00'), L_EXTENDEDPRICE=Decimal('74848.44'), L_DISCOUNT=Decimal('0.07'), L_TAX=Decimal('0.08'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1993, 7, 17), L_COMMITDATE=datetime.date(1993, 8, 8), L_RECEIPTDATE=datetime.date(1993, 8, 12), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='FOB', L_COMMENT='ckly along the even packages. regular in'),
#  Row(L_ORDERKEY=51426277, L_PARTKEY=1439225, L_SUPPKEY=14268, L_LINENUMBER=3, L_QUANTITY=Decimal('6.00'), L_EXTENDEDPRICE=Decimal('6984.90'), L_DISCOUNT=Decimal('0.02'), L_TAX=Decimal('0.01'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1993, 7, 14), L_COMMITDATE=datetime.date(1993, 6, 30), L_RECEIPTDATE=datetime.date(1993, 8, 10), L_SHIPINSTRUCT='NONE', L_SHIPMODE='TRUCK', L_COMMENT='y silent accounts. furiously ev'),
#  Row(L_ORDERKEY=51426277, L_PARTKEY=1049881, L_SUPPKEY=49882, L_LINENUMBER=4, L_QUANTITY=Decimal('9.00'), L_EXTENDEDPRICE=Decimal('16477.47'), L_DISCOUNT=Decimal('0.00'), L_TAX=Decimal('0.03'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1993, 6, 22), L_COMMITDATE=datetime.date(1993, 8, 3), L_RECEIPTDATE=datetime.date(1993, 7, 6), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='REG AIR', L_COMMENT='ironic accounts. carefully'),
#  Row(L_ORDERKEY=51426277, L_PARTKEY=1338613, L_SUPPKEY=63627, L_LINENUMBER=5, L_QUANTITY=Decimal('38.00'), L_EXTENDEDPRICE=Decimal('62758.90'), L_DISCOUNT=Decimal('0.06'), L_TAX=Decimal('0.03'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1993, 7, 7), L_COMMITDATE=datetime.date(1993, 6, 25), L_RECEIPTDATE=datetime.date(1993, 7, 20), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='MAIL', L_COMMENT='nding accounts are furiously. '),
#  Row(L_ORDERKEY=51426278, L_PARTKEY=1196918, L_SUPPKEY=46941, L_LINENUMBER=1, L_QUANTITY=Decimal('45.00'), L_EXTENDEDPRICE=Decimal('90668.70'), L_DISCOUNT=Decimal('0.08'), L_TAX=Decimal('0.03'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1995, 10, 22), L_COMMITDATE=datetime.date(1995, 10, 19), L_RECEIPTDATE=datetime.date(1995, 11, 10), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='REG AIR', L_COMMENT='hely regular pinto b'),
#  Row(L_ORDERKEY=51426278, L_PARTKEY=600750, L_SUPPKEY=50763, L_LINENUMBER=2, L_QUANTITY=Decimal('21.00'), L_EXTENDEDPRICE=Decimal('34665.12'), L_DISCOUNT=Decimal('0.05'), L_TAX=Decimal('0.03'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1995, 9, 13), L_COMMITDATE=datetime.date(1995, 10, 12), L_RECEIPTDATE=datetime.date(1995, 9, 16), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='RAIL', L_COMMENT=' boost according to the'),
#  Row(L_ORDERKEY=51426278, L_PARTKEY=793519, L_SUPPKEY=18527, L_LINENUMBER=3, L_QUANTITY=Decimal('41.00'), L_EXTENDEDPRICE=Decimal('66111.68'), L_DISCOUNT=Decimal('0.09'), L_TAX=Decimal('0.06'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1996, 1, 3), L_COMMITDATE=datetime.date(1995, 11, 5), L_RECEIPTDATE=datetime.date(1996, 1, 30), L_SHIPINSTRUCT='NONE', L_SHIPMODE='SHIP', L_COMMENT=' accounts. carefully regular de'),
#  Row(L_ORDERKEY=51426278, L_PARTKEY=670123, L_SUPPKEY=95130, L_LINENUMBER=4, L_QUANTITY=Decimal('22.00'), L_EXTENDEDPRICE=Decimal('24047.98'), L_DISCOUNT=Decimal('0.07'), L_TAX=Decimal('0.00'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1995, 12, 18), L_COMMITDATE=datetime.date(1995, 11, 17), L_RECEIPTDATE=datetime.date(1995, 12, 25), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='AIR', L_COMMENT='ing to the blithely unusual pla'),
#  Row(L_ORDERKEY=51426278, L_PARTKEY=751298, L_SUPPKEY=1313, L_LINENUMBER=5, L_QUANTITY=Decimal('28.00'), L_EXTENDEDPRICE=Decimal('37779.28'), L_DISCOUNT=Decimal('0.07'), L_TAX=Decimal('0.07'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1995, 12, 22), L_COMMITDATE=datetime.date(1995, 11, 29), L_RECEIPTDATE=datetime.date(1996, 1, 14), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='AIR', L_COMMENT='ffily blithely final attainments.'),
#  Row(L_ORDERKEY=51426278, L_PARTKEY=1056650, L_SUPPKEY=56651, L_LINENUMBER=6, L_QUANTITY=Decimal('7.00'), L_EXTENDEDPRICE=Decimal('11246.20'), L_DISCOUNT=Decimal('0.05'), L_TAX=Decimal('0.04'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1995, 12, 11), L_COMMITDATE=datetime.date(1995, 10, 18), L_RECEIPTDATE=datetime.date(1995, 12, 21), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='TRUCK', L_COMMENT='ronic somas.'),
#  Row(L_ORDERKEY=51426278, L_PARTKEY=1113908, L_SUPPKEY=63931, L_LINENUMBER=7, L_QUANTITY=Decimal('25.00'), L_EXTENDEDPRICE=Decimal('48046.25'), L_DISCOUNT=Decimal('0.04'), L_TAX=Decimal('0.03'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1995, 9, 15), L_COMMITDATE=datetime.date(1995, 11, 27), L_RECEIPTDATE=datetime.date(1995, 9, 17), L_SHIPINSTRUCT='NONE', L_SHIPMODE='SHIP', L_COMMENT='etect carefully. '),
#  Row(L_ORDERKEY=51426279, L_PARTKEY=1448358, L_SUPPKEY=23401, L_LINENUMBER=1, L_QUANTITY=Decimal('17.00'), L_EXTENDEDPRICE=Decimal('22206.76'), L_DISCOUNT=Decimal('0.00'), L_TAX=Decimal('0.06'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 10, 14), L_COMMITDATE=datetime.date(1994, 8, 16), L_RECEIPTDATE=datetime.date(1994, 11, 3), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='SHIP', L_COMMENT='y unusual requests. express asymptotes'),
#  Row(L_ORDERKEY=51426279, L_PARTKEY=541167, L_SUPPKEY=66173, L_LINENUMBER=2, L_QUANTITY=Decimal('41.00'), L_EXTENDEDPRICE=Decimal('49533.74'), L_DISCOUNT=Decimal('0.00'), L_TAX=Decimal('0.05'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 10, 27), L_COMMITDATE=datetime.date(1994, 9, 11), L_RECEIPTDATE=datetime.date(1994, 11, 14), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='AIR', L_COMMENT='tes are pl'),
#  Row(L_ORDERKEY=51426279, L_PARTKEY=1384246, L_SUPPKEY=9260, L_LINENUMBER=3, L_QUANTITY=Decimal('43.00'), L_EXTENDEDPRICE=Decimal('57197.74'), L_DISCOUNT=Decimal('0.05'), L_TAX=Decimal('0.01'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 8, 11), L_COMMITDATE=datetime.date(1994, 8, 14), L_RECEIPTDATE=datetime.date(1994, 8, 21), L_SHIPINSTRUCT='NONE', L_SHIPMODE='SHIP', L_COMMENT='ly unusual accounts. carefully regular f'),
#  Row(L_ORDERKEY=51426304, L_PARTKEY=1005752, L_SUPPKEY=80783, L_LINENUMBER=1, L_QUANTITY=Decimal('44.00'), L_EXTENDEDPRICE=Decimal('72938.80'), L_DISCOUNT=Decimal('0.02'), L_TAX=Decimal('0.06'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1998, 11, 2), L_COMMITDATE=datetime.date(1998, 9, 18), L_RECEIPTDATE=datetime.date(1998, 11, 19), L_SHIPINSTRUCT='NONE', L_SHIPMODE='AIR', L_COMMENT='dependencies x-ray fur'),
#  Row(L_ORDERKEY=51426304, L_PARTKEY=1660145, L_SUPPKEY=60146, L_LINENUMBER=2, L_QUANTITY=Decimal('34.00'), L_EXTENDEDPRICE=Decimal('37572.04'), L_DISCOUNT=Decimal('0.07'), L_TAX=Decimal('0.08'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1998, 11, 8), L_COMMITDATE=datetime.date(1998, 9, 12), L_RECEIPTDATE=datetime.date(1998, 11, 12), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='AIR', L_COMMENT='eep quickly. '),
#  Row(L_ORDERKEY=51426304, L_PARTKEY=54721, L_SUPPKEY=29722, L_LINENUMBER=3, L_QUANTITY=Decimal('24.00'), L_EXTENDEDPRICE=Decimal('40217.28'), L_DISCOUNT=Decimal('0.05'), L_TAX=Decimal('0.06'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1998, 11, 10), L_COMMITDATE=datetime.date(1998, 9, 11), L_RECEIPTDATE=datetime.date(1998, 12, 10), L_SHIPINSTRUCT='NONE', L_SHIPMODE='REG AIR', L_COMMENT='lithely even courts'),
#  Row(L_ORDERKEY=51426304, L_PARTKEY=1690959, L_SUPPKEY=15976, L_LINENUMBER=4, L_QUANTITY=Decimal('13.00'), L_EXTENDEDPRICE=Decimal('25348.31'), L_DISCOUNT=Decimal('0.05'), L_TAX=Decimal('0.07'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1998, 11, 6), L_COMMITDATE=datetime.date(1998, 9, 4), L_RECEIPTDATE=datetime.date(1998, 11, 22), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='SHIP', L_COMMENT='cording to the final packages. regular dep'),
#  Row(L_ORDERKEY=51426305, L_PARTKEY=1966814, L_SUPPKEY=16853, L_LINENUMBER=1, L_QUANTITY=Decimal('14.00'), L_EXTENDEDPRICE=Decimal('26330.08'), L_DISCOUNT=Decimal('0.07'), L_TAX=Decimal('0.06'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1995, 3, 14), L_COMMITDATE=datetime.date(1995, 2, 13), L_RECEIPTDATE=datetime.date(1995, 3, 17), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='MAIL', L_COMMENT='usly across the slyly even re'),
#  Row(L_ORDERKEY=51426305, L_PARTKEY=242807, L_SUPPKEY=17814, L_LINENUMBER=2, L_QUANTITY=Decimal('12.00'), L_EXTENDEDPRICE=Decimal('20997.48'), L_DISCOUNT=Decimal('0.03'), L_TAX=Decimal('0.06'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1995, 2, 24), L_COMMITDATE=datetime.date(1995, 3, 3), L_RECEIPTDATE=datetime.date(1995, 3, 9), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='AIR', L_COMMENT='ding sentiments. quickly bold de'),
# ...
#  Row(L_ORDERKEY=51427170, L_PARTKEY=1296459, L_SUPPKEY=71496, L_LINENUMBER=3, L_QUANTITY=Decimal('34.00'), L_EXTENDEDPRICE=Decimal('49483.26'), L_DISCOUNT=Decimal('0.00'), L_TAX=Decimal('0.07'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 2, 7), L_COMMITDATE=datetime.date(1994, 3, 28), L_RECEIPTDATE=datetime.date(1994, 3, 2), L_SHIPINSTRUCT='NONE', L_SHIPMODE='MAIL', L_COMMENT='lly final asymptotes hag'),
#  Row(L_ORDERKEY=51427170, L_PARTKEY=1574380, L_SUPPKEY=74381, L_LINENUMBER=4, L_QUANTITY=Decimal('18.00'), L_EXTENDEDPRICE=Decimal('26177.58'), L_DISCOUNT=Decimal('0.01'), L_TAX=Decimal('0.00'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 3, 14), L_COMMITDATE=datetime.date(1994, 3, 11), L_RECEIPTDATE=datetime.date(1994, 3, 20), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='AIR', L_COMMENT='usly special platelets nag'),
#  Row(L_ORDERKEY=51427171, L_PARTKEY=146061, L_SUPPKEY=96064, L_LINENUMBER=1, L_QUANTITY=Decimal('19.00'), L_EXTENDEDPRICE=Decimal('21034.14'), L_DISCOUNT=Decimal('0.03'), L_TAX=Decimal('0.06'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1995, 7, 10), L_COMMITDATE=datetime.date(1995, 9, 14), L_RECEIPTDATE=datetime.date(1995, 7, 28), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='TRUCK', L_COMMENT='hins. ironic dolphins affix. blithely'),
#  Row(L_ORDERKEY=51427172, L_PARTKEY=1351961, L_SUPPKEY=1988, L_LINENUMBER=1, L_QUANTITY=Decimal('28.00'), L_EXTENDEDPRICE=Decimal('56361.20'), L_DISCOUNT=Decimal('0.08'), L_TAX=Decimal('0.02'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 9, 1), L_COMMITDATE=datetime.date(1994, 11, 1), L_RECEIPTDATE=datetime.date(1994, 9, 23), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='AIR', L_COMMENT='ites nag carefully furiousl'),
#  Row(L_ORDERKEY=51427172, L_PARTKEY=399645, L_SUPPKEY=99646, L_LINENUMBER=2, L_QUANTITY=Decimal('27.00'), L_EXTENDEDPRICE=Decimal('47105.01'), L_DISCOUNT=Decimal('0.05'), L_TAX=Decimal('0.07'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 10, 19), L_COMMITDATE=datetime.date(1994, 9, 6), L_RECEIPTDATE=datetime.date(1994, 10, 27), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='MAIL', L_COMMENT='riously evenly ironi'),
#  Row(L_ORDERKEY=51427172, L_PARTKEY=833452, L_SUPPKEY=58461, L_LINENUMBER=3, L_QUANTITY=Decimal('13.00'), L_EXTENDEDPRICE=Decimal('18010.33'), L_DISCOUNT=Decimal('0.06'), L_TAX=Decimal('0.01'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1994, 10, 26), L_COMMITDATE=datetime.date(1994, 9, 26), L_RECEIPTDATE=datetime.date(1994, 10, 30), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='RAIL', L_COMMENT='ic accounts'),
#  Row(L_ORDERKEY=51427173, L_PARTKEY=23707, L_SUPPKEY=48708, L_LINENUMBER=1, L_QUANTITY=Decimal('33.00'), L_EXTENDEDPRICE=Decimal('53813.10'), L_DISCOUNT=Decimal('0.07'), L_TAX=Decimal('0.00'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1993, 10, 17), L_COMMITDATE=datetime.date(1993, 11, 16), L_RECEIPTDATE=datetime.date(1993, 11, 2), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='TRUCK', L_COMMENT=' sleep among the furiously f'),
#  Row(L_ORDERKEY=51427173, L_PARTKEY=440569, L_SUPPKEY=40570, L_LINENUMBER=2, L_QUANTITY=Decimal('20.00'), L_EXTENDEDPRICE=Decimal('30190.80'), L_DISCOUNT=Decimal('0.07'), L_TAX=Decimal('0.05'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1993, 12, 3), L_COMMITDATE=datetime.date(1993, 10, 5), L_RECEIPTDATE=datetime.date(1993, 12, 23), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='TRUCK', L_COMMENT='bold braids. ideas promise. pinto beans aff'),
#  Row(L_ORDERKEY=51427173, L_PARTKEY=635898, L_SUPPKEY=85911, L_LINENUMBER=3, L_QUANTITY=Decimal('17.00'), L_EXTENDEDPRICE=Decimal('31175.62'), L_DISCOUNT=Decimal('0.08'), L_TAX=Decimal('0.02'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1993, 10, 26), L_COMMITDATE=datetime.date(1993, 12, 2), L_RECEIPTDATE=datetime.date(1993, 10, 29), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='SHIP', L_COMMENT='sts. slyly sil'),
#  Row(L_ORDERKEY=51427173, L_PARTKEY=1531424, L_SUPPKEY=6470, L_LINENUMBER=4, L_QUANTITY=Decimal('32.00'), L_EXTENDEDPRICE=Decimal('46571.20'), L_DISCOUNT=Decimal('0.01'), L_TAX=Decimal('0.04'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1993, 10, 26), L_COMMITDATE=datetime.date(1993, 11, 1), L_RECEIPTDATE=datetime.date(1993, 11, 16), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='RAIL', L_COMMENT=' braids detect blithely after t'),
#  Row(L_ORDERKEY=51427173, L_PARTKEY=637325, L_SUPPKEY=62332, L_LINENUMBER=5, L_QUANTITY=Decimal('13.00'), L_EXTENDEDPRICE=Decimal('16409.77'), L_DISCOUNT=Decimal('0.09'), L_TAX=Decimal('0.01'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1993, 11, 24), L_COMMITDATE=datetime.date(1993, 11, 4), L_RECEIPTDATE=datetime.date(1993, 11, 25), L_SHIPINSTRUCT='NONE', L_SHIPMODE='TRUCK', L_COMMENT='tes. brave accounts cajole blithely b'),
#  Row(L_ORDERKEY=51427173, L_PARTKEY=1515395, L_SUPPKEY=15396, L_LINENUMBER=6, L_QUANTITY=Decimal('50.00'), L_EXTENDEDPRICE=Decimal('70516.00'), L_DISCOUNT=Decimal('0.00'), L_TAX=Decimal('0.01'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1993, 12, 3), L_COMMITDATE=datetime.date(1993, 11, 23), L_RECEIPTDATE=datetime.date(1993, 12, 19), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='SHIP', L_COMMENT='es detect '),
#  Row(L_ORDERKEY=51427174, L_PARTKEY=70105, L_SUPPKEY=70106, L_LINENUMBER=1, L_QUANTITY=Decimal('50.00'), L_EXTENDEDPRICE=Decimal('53755.00'), L_DISCOUNT=Decimal('0.04'), L_TAX=Decimal('0.07'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1998, 3, 14), L_COMMITDATE=datetime.date(1998, 3, 8), L_RECEIPTDATE=datetime.date(1998, 3, 29), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='SHIP', L_COMMENT='press deposits. quickly unusual theodolit'),
#  Row(L_ORDERKEY=51427174, L_PARTKEY=239873, L_SUPPKEY=89878, L_LINENUMBER=2, L_QUANTITY=Decimal('35.00'), L_EXTENDEDPRICE=Decimal('63450.10'), L_DISCOUNT=Decimal('0.01'), L_TAX=Decimal('0.00'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1998, 4, 23), L_COMMITDATE=datetime.date(1998, 4, 16), L_RECEIPTDATE=datetime.date(1998, 4, 30), L_SHIPINSTRUCT='NONE', L_SHIPMODE='MAIL', L_COMMENT='tes sleep slyl'),
#  Row(L_ORDERKEY=51427174, L_PARTKEY=1531292, L_SUPPKEY=6338, L_LINENUMBER=3, L_QUANTITY=Decimal('48.00'), L_EXTENDEDPRICE=Decimal('63514.56'), L_DISCOUNT=Decimal('0.03'), L_TAX=Decimal('0.06'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1998, 5, 16), L_COMMITDATE=datetime.date(1998, 5, 5), L_RECEIPTDATE=datetime.date(1998, 6, 2), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='MAIL', L_COMMENT='ly express t'),
#  Row(L_ORDERKEY=51427174, L_PARTKEY=418049, L_SUPPKEY=93062, L_LINENUMBER=4, L_QUANTITY=Decimal('32.00'), L_EXTENDEDPRICE=Decimal('30944.64'), L_DISCOUNT=Decimal('0.10'), L_TAX=Decimal('0.04'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1998, 3, 14), L_COMMITDATE=datetime.date(1998, 3, 13), L_RECEIPTDATE=datetime.date(1998, 3, 23), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='TRUCK', L_COMMENT='are across t'),
#  Row(L_ORDERKEY=51427174, L_PARTKEY=134038, L_SUPPKEY=59040, L_LINENUMBER=5, L_QUANTITY=Decimal('23.00'), L_EXTENDEDPRICE=Decimal('24656.69'), L_DISCOUNT=Decimal('0.01'), L_TAX=Decimal('0.07'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1998, 4, 14), L_COMMITDATE=datetime.date(1998, 3, 7), L_RECEIPTDATE=datetime.date(1998, 5, 13), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='REG AIR', L_COMMENT='ecial accounts at the furiously idle'),
#  Row(L_ORDERKEY=51427175, L_PARTKEY=630963, L_SUPPKEY=5982, L_LINENUMBER=1, L_QUANTITY=Decimal('2.00'), L_EXTENDEDPRICE=Decimal('3787.86'), L_DISCOUNT=Decimal('0.07'), L_TAX=Decimal('0.03'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1992, 12, 1), L_COMMITDATE=datetime.date(1992, 12, 29), L_RECEIPTDATE=datetime.date(1992, 12, 15), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='RAIL', L_COMMENT='express patterns alongside'),
#  Row(L_ORDERKEY=51427175, L_PARTKEY=588580, L_SUPPKEY=13586, L_LINENUMBER=2, L_QUANTITY=Decimal('19.00'), L_EXTENDEDPRICE=Decimal('31702.64'), L_DISCOUNT=Decimal('0.08'), L_TAX=Decimal('0.00'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1993, 1, 2), L_COMMITDATE=datetime.date(1993, 1, 29), L_RECEIPTDATE=datetime.date(1993, 1, 19), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='REG AIR', L_COMMENT=' after the ironic packages. pen'),
#  Row(L_ORDERKEY=51427175, L_PARTKEY=258496, L_SUPPKEY=33503, L_LINENUMBER=3, L_QUANTITY=Decimal('43.00'), L_EXTENDEDPRICE=Decimal('62542.64'), L_DISCOUNT=Decimal('0.08'), L_TAX=Decimal('0.01'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1993, 2, 12), L_COMMITDATE=datetime.date(1993, 1, 12), L_RECEIPTDATE=datetime.date(1993, 2, 25), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='AIR', L_COMMENT='l accounts grow slyly regular courts. reg'),
#  Row(L_ORDERKEY=51427175, L_PARTKEY=539464, L_SUPPKEY=64470, L_LINENUMBER=4, L_QUANTITY=Decimal('9.00'), L_EXTENDEDPRICE=Decimal('13530.96'), L_DISCOUNT=Decimal('0.06'), L_TAX=Decimal('0.04'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1993, 1, 13), L_COMMITDATE=datetime.date(1992, 12, 30), L_RECEIPTDATE=datetime.date(1993, 1, 23), L_SHIPINSTRUCT='TAKE BACK RETURN', L_SHIPMODE='AIR', L_COMMENT='ully pending asymptotes haggle fl'),
#  Row(L_ORDERKEY=51427175, L_PARTKEY=767785, L_SUPPKEY=17800, L_LINENUMBER=5, L_QUANTITY=Decimal('17.00'), L_EXTENDEDPRICE=Decimal('31496.75'), L_DISCOUNT=Decimal('0.08'), L_TAX=Decimal('0.08'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1992, 12, 6), L_COMMITDATE=datetime.date(1993, 1, 12), L_RECEIPTDATE=datetime.date(1992, 12, 14), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='REG AIR', L_COMMENT='requests. express, unusual instru'),
#  Row(L_ORDERKEY=51427175, L_PARTKEY=147751, L_SUPPKEY=72753, L_LINENUMBER=6, L_QUANTITY=Decimal('32.00'), L_EXTENDEDPRICE=Decimal('57560.00'), L_DISCOUNT=Decimal('0.06'), L_TAX=Decimal('0.03'), L_RETURNFLAG='A', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1993, 2, 8), L_COMMITDATE=datetime.date(1993, 2, 12), L_RECEIPTDATE=datetime.date(1993, 2, 11), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='FOB', L_COMMENT='along the '),
#  Row(L_ORDERKEY=51427175, L_PARTKEY=1247862, L_SUPPKEY=97887, L_LINENUMBER=7, L_QUANTITY=Decimal('3.00'), L_EXTENDEDPRICE=Decimal('5429.40'), L_DISCOUNT=Decimal('0.03'), L_TAX=Decimal('0.05'), L_RETURNFLAG='R', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1993, 1, 16), L_COMMITDATE=datetime.date(1993, 1, 27), L_RECEIPTDATE=datetime.date(1993, 1, 19), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='REG AIR', L_COMMENT=' pinto beans among t'),
#  Row(L_ORDERKEY=51427200, L_PARTKEY=804451, L_SUPPKEY=79476, L_LINENUMBER=1, L_QUANTITY=Decimal('17.00'), L_EXTENDEDPRICE=Decimal('23041.97'), L_DISCOUNT=Decimal('0.07'), L_TAX=Decimal('0.07'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1995, 7, 29), L_COMMITDATE=datetime.date(1995, 7, 10), L_RECEIPTDATE=datetime.date(1995, 8, 9), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='REG AIR', L_COMMENT='regular foxes. f'),
#  Row(L_ORDERKEY=51427200, L_PARTKEY=401091, L_SUPPKEY=26096, L_LINENUMBER=2, L_QUANTITY=Decimal('36.00'), L_EXTENDEDPRICE=Decimal('35714.52'), L_DISCOUNT=Decimal('0.05'), L_TAX=Decimal('0.05'), L_RETURNFLAG='N', L_LINESTATUS='F', L_SHIPDATE=datetime.date(1995, 6, 6), L_COMMITDATE=datetime.date(1995, 7, 5), L_RECEIPTDATE=datetime.date(1995, 6, 22), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='TRUCK', L_COMMENT='e against the carefully re'),
#  Row(L_ORDERKEY=51427201, L_PARTKEY=1525501, L_SUPPKEY=50517, L_LINENUMBER=1, L_QUANTITY=Decimal('17.00'), L_EXTENDEDPRICE=Decimal('25949.31'), L_DISCOUNT=Decimal('0.00'), L_TAX=Decimal('0.07'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 4, 7), L_COMMITDATE=datetime.date(1997, 4, 17), L_RECEIPTDATE=datetime.date(1997, 4, 14), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='RAIL', L_COMMENT=' beans. furiously regular pinto beans '),
#  Row(L_ORDERKEY=51427201, L_PARTKEY=1081275, L_SUPPKEY=6286, L_LINENUMBER=2, L_QUANTITY=Decimal('15.00'), L_EXTENDEDPRICE=Decimal('18843.30'), L_DISCOUNT=Decimal('0.00'), L_TAX=Decimal('0.06'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 3, 18), L_COMMITDATE=datetime.date(1997, 4, 24), L_RECEIPTDATE=datetime.date(1997, 4, 12), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='TRUCK', L_COMMENT='ely final re'),
#  Row(L_ORDERKEY=51427201, L_PARTKEY=979844, L_SUPPKEY=29863, L_LINENUMBER=3, L_QUANTITY=Decimal('42.00'), L_EXTENDEDPRICE=Decimal('80799.60'), L_DISCOUNT=Decimal('0.10'), L_TAX=Decimal('0.03'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 2, 7), L_COMMITDATE=datetime.date(1997, 4, 3), L_RECEIPTDATE=datetime.date(1997, 3, 3), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='REG AIR', L_COMMENT='y final requests. even, bold dependencie'),
#  Row(L_ORDERKEY=51427202, L_PARTKEY=1049388, L_SUPPKEY=24419, L_LINENUMBER=1, L_QUANTITY=Decimal('39.00'), L_EXTENDEDPRICE=Decimal('52155.87'), L_DISCOUNT=Decimal('0.03'), L_TAX=Decimal('0.00'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 12, 7), L_COMMITDATE=datetime.date(1997, 11, 27), L_RECEIPTDATE=datetime.date(1997, 12, 12), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='REG AIR', L_COMMENT='ing to the'),
#  Row(L_ORDERKEY=51427202, L_PARTKEY=1047561, L_SUPPKEY=97582, L_LINENUMBER=2, L_QUANTITY=Decimal('23.00'), L_EXTENDEDPRICE=Decimal('34695.73'), L_DISCOUNT=Decimal('0.05'), L_TAX=Decimal('0.02'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 11, 4), L_COMMITDATE=datetime.date(1997, 12, 5), L_RECEIPTDATE=datetime.date(1997, 11, 24), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='FOB', L_COMMENT='e fluffily ironic pinto'),
#  Row(L_ORDERKEY=51427202, L_PARTKEY=348095, L_SUPPKEY=23105, L_LINENUMBER=3, L_QUANTITY=Decimal('31.00'), L_EXTENDEDPRICE=Decimal('35435.48'), L_DISCOUNT=Decimal('0.03'), L_TAX=Decimal('0.02'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 10, 3), L_COMMITDATE=datetime.date(1997, 12, 2), L_RECEIPTDATE=datetime.date(1997, 10, 12), L_SHIPINSTRUCT='COLLECT COD', L_SHIPMODE='TRUCK', L_COMMENT='s around the careful'),
#  Row(L_ORDERKEY=51427202, L_PARTKEY=429534, L_SUPPKEY=29535, L_LINENUMBER=4, L_QUANTITY=Decimal('40.00'), L_EXTENDEDPRICE=Decimal('58540.40'), L_DISCOUNT=Decimal('0.08'), L_TAX=Decimal('0.00'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1998, 1, 3), L_COMMITDATE=datetime.date(1997, 12, 19), L_RECEIPTDATE=datetime.date(1998, 1, 10), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='MAIL', L_COMMENT='nic dolphins nod. furiously even sauterne'),
#  Row(L_ORDERKEY=51427202, L_PARTKEY=1172062, L_SUPPKEY=47096, L_LINENUMBER=5, L_QUANTITY=Decimal('33.00'), L_EXTENDEDPRICE=Decimal('37422.33'), L_DISCOUNT=Decimal('0.03'), L_TAX=Decimal('0.04'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 12, 10), L_COMMITDATE=datetime.date(1997, 12, 26), L_RECEIPTDATE=datetime.date(1998, 1, 9), L_SHIPINSTRUCT='DELIVER IN PERSON', L_SHIPMODE='REG AIR', L_COMMENT='ly ironic requests. blit'),
#  Row(L_ORDERKEY=51427202, L_PARTKEY=841384, L_SUPPKEY=41385, L_LINENUMBER=6, L_QUANTITY=Decimal('38.00'), L_EXTENDEDPRICE=Decimal('50362.92'), L_DISCOUNT=Decimal('0.06'), L_TAX=Decimal('0.03'), L_RETURNFLAG='N', L_LINESTATUS='O', L_SHIPDATE=datetime.date(1997, 10, 17), L_COMMITDATE=datetime.date(1997, 11, 20), L_RECEIPTDATE=datetime.date(1997, 10, 21), L_SHIPINSTRUCT='NONE', L_SHIPMODE='REG AIR', L_COMMENT='the special, ')]

# %%
for row in df.collect():
    print(f"{row.L_ORDERKEY}: {row.L_EXTENDEDPRICE}")
# Out:
# 51426183: 13104.24
# 51426183: 5653.32
# 51426208: 40405.02
# 51426208: 41019.42
# 51426208: 34977.92
# 51426208: 78705.48
# 51426208: 60014.85
# 51426208: 12353.25
# 51426208: 2374.28
# 51426209: 4579.47
# 51426210: 82098.96
# 51426210: 62099.73
# 51426210: 46204.62
# 51426211: 5565.55
# 51426211: 37692.77
# 51426211: 7186.76
# 51426211: 38499.52
# 51426211: 91459.65
# 51426211: 60573.44
# 51426211: 5375.50
# 51426212: 77896.31
# 51426213: 32531.20
# 51426214: 58183.61
# 51426214: 29883.69
# 51426214: 6661.00
# 51426214: 57618.36
# 51426215: 57724.94
# 51426215: 7303.68
# 51426215: 19876.16
# 51426215: 47364.46
# 51426240: 30683.38
# 51426240: 53556.75
# 51426240: 69833.96
# 51426240: 63113.50
# 51426240: 46621.27
# 51426240: 28900.80
# 51426241: 24293.85
# 51427139: 54211.60
# 51427139: 59578.59
# 51427139: 33060.87
# 51427139: 20855.10
# 51427139: 25073.55
# 51427140: 52152.36
# 51427140: 32448.92
# 51427141: 13958.16
# 51427141: 42286.65
# 51427141: 41839.20
# 51427141: 24935.52
# 51427141: 47340.85
# 51427141: 67386.44
# 51427141: 50656.80
# 51427142: 16155.90
# 51427142: 59491.88
# 51427142: 25479.15
# 51427142: 53127.04
# 51427142: 11621.88
# 51427142: 21691.08
# 51427143: 12829.83
# 51427143: 7462.75
# 51427143: 45945.00
# 51427143: 48017.55
# 51427143: 50701.53
# 51427143: 68573.73
# 51427168: 60459.20
# 51427169: 20936.64
# 51427169: 12409.18
# 51427169: 17734.99
# 51427169: 26995.65
# 51427169: 36846.30
# 51427169: 75754.40
# 51427170: 29168.83
# 51427170: 46531.94
# 51427170: 49483.26
# 51427170: 26177.58
# 51427171: 21034.14
# 51427172: 56361.20
# 51427172: 47105.01
# 51427172: 18010.33
# 51427173: 53813.10
# 51427173: 30190.80
# 51427173: 31175.62
# 51427173: 46571.20
# 51427173: 16409.77
# 51427173: 70516.00
# 51427174: 53755.00
# 51427174: 63450.10
# 51427174: 63514.56
# 51427174: 30944.64
# 51427174: 24656.69
# 51427175: 3787.86
# 51427175: 31702.64
# 51427175: 62542.64
# 51427175: 13530.96
# 51427175: 31496.75
# 51427175: 57560.00
# 51427175: 5429.40
# 51427200: 23041.97
# 51427200: 35714.52
# 51427201: 25949.31
# 51427201: 18843.30
# 51427201: 80799.60
# 51427202: 52155.87
# 51427202: 34695.73
# 51427202: 35435.48
# 51427202: 58540.40
# 51427202: 37422.33
# 51427202: 50362.92

# %% [markdown]
# ### Set Database and Schema for Session

# %%
sp_session.use_database("snowflake_sample_data")

sp_session.use_schema("tpch_sf10")

# %% [markdown]
# ### Set Table for Session

# %%
df = sp_session.table("lineitem")

# %% [markdown]
# ### Select from Dataframe and Filter

# %%
from_date = datetime.date(1997, 1, 1)
to_date = datetime.date(1997, 12, 31)

df = df.select(
    "L_SHIPDATE",
    "L_EXTENDEDPRICE",
    "L_SHIPMODE",
    "L_QUANTITY",
    "L_DISCOUNT",
).filter(
    functions.col("L_SHIPDATE").between(from_date, to_date)
)

# %%
df.show()
# Out:
# ---------------------------------------------------------------------------------
# |"L_SHIPDATE"  |"L_EXTENDEDPRICE"  |"L_SHIPMODE"  |"L_QUANTITY"  |"L_DISCOUNT"  |
# ---------------------------------------------------------------------------------
# |1997-07-03    |5565.55            |SHIP          |5.00          |0.01          |
# |1997-05-19    |37692.77           |RAIL          |19.00         |0.04          |
# |1997-08-10    |7186.76            |RAIL          |4.00          |0.09          |
# |1997-07-11    |38499.52           |FOB           |32.00         |0.00          |
# |1997-06-11    |91459.65           |REG AIR       |47.00         |0.07          |
# |1997-07-29    |60573.44           |AIR           |32.00         |0.10          |
# |1997-05-20    |5375.50            |FOB           |5.00          |0.01          |
# |1997-06-04    |77896.31           |SHIP          |41.00         |0.04          |
# |1997-07-03    |47745.28           |AIR           |44.00         |0.00          |
# |1997-07-01    |38205.44           |RAIL          |26.00         |0.05          |
# ---------------------------------------------------------------------------------

# %% [markdown]
# ### Create New Columns

# %%
df = df.with_column(
    "REVENUE", 
    (functions.col("L_EXTENDEDPRICE") - (functions.col("L_EXTENDEDPRICE") * functions.col("L_DISCOUNT"))) * functions.col("L_QUANTITY")
)

# %%
df.show()
# Out:
# --------------------------------------------------------------------------------------------------
# |"L_SHIPDATE"  |"L_EXTENDEDPRICE"  |"L_SHIPMODE"  |"L_QUANTITY"  |"L_DISCOUNT"  |"REVENUE"       |
# --------------------------------------------------------------------------------------------------
# |1997-07-03    |5565.55            |SHIP          |5.00          |0.01          |27549.472500    |
# |1997-05-19    |37692.77           |RAIL          |19.00         |0.04          |687516.124800   |
# |1997-08-10    |7186.76            |RAIL          |4.00          |0.09          |26159.806400    |
# |1997-07-11    |38499.52           |FOB           |32.00         |0.00          |1231984.640000  |
# |1997-06-11    |91459.65           |REG AIR       |47.00         |0.07          |3997701.301500  |
# |1997-07-29    |60573.44           |AIR           |32.00         |0.10          |1744515.072000  |
# |1997-05-20    |5375.50            |FOB           |5.00          |0.01          |26608.725000    |
# |1997-06-04    |77896.31           |SHIP          |41.00         |0.04          |3065998.761600  |
# |1997-07-03    |47745.28           |AIR           |44.00         |0.00          |2100792.320000  |
# |1997-07-01    |38205.44           |RAIL          |26.00         |0.05          |943674.368000   |
# --------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Grouping

# %%
total_1997 = df.group_by("L_SHIPMODE").agg(functions.sum("REVENUE").alias("TOTAL_REVENUE"))

# %%
total_1997.show()
# Out:
# ---------------------------------------
# |"L_SHIPMODE"  |"TOTAL_REVENUE"       |
# ---------------------------------------
# |TRUCK         |1590733688302.036700  |
# |AIR           |1588489012314.814700  |
# |RAIL          |1593265749227.381000  |
# |SHIP          |1587705642771.441000  |
# |MAIL          |1589584697330.409300  |
# |FOB           |1588274810649.676300  |
# |REG AIR       |1588413005265.937100  |
# ---------------------------------------

# %% [markdown]
# ### Joining Dataframes

# %%
# Create a second dataframe for 1998
df2 = sp_session.table("lineitem")

from_date = datetime.date(1998, 1, 1)
to_date = datetime.date(1998, 12, 31)

df2 = df2.select(
    "L_SHIPDATE",
    "L_EXTENDEDPRICE",
    "L_SHIPMODE",
    "L_QUANTITY",
    "L_DISCOUNT",
).filter(
    functions.col("L_SHIPDATE").between(from_date, to_date)
)

df2 = df2.with_column(
    "REVENUE", 
    (functions.col("L_EXTENDEDPRICE") - (functions.col("L_EXTENDEDPRICE") * functions.col("L_DISCOUNT"))) * functions.col("L_QUANTITY")
)

total_1998 = df2.group_by("L_SHIPMODE").agg(functions.sum("REVENUE").alias("TOTAL_REVENUE_1998"))

# %%
# Rename column in 1997 dataframe
total_1997.with_column_renamed(functions.col("TOTAL_REVENUE"), "TOTAL_REVENUE_1997").show()
# Out:
# ---------------------------------------
# |"L_SHIPMODE"  |"TOTAL_REVENUE_1997"  |
# ---------------------------------------
# |TRUCK         |1590733688302.036700  |
# |FOB           |1588274810649.676300  |
# |AIR           |1588489012314.814700  |
# |REG AIR       |1588413005265.937100  |
# |SHIP          |1587705642771.441000  |
# |MAIL          |1589584697330.409300  |
# |RAIL          |1593265749227.381000  |
# ---------------------------------------

# %%
total_1997 = total_1997.with_column_renamed(functions.col("TOTAL_REVENUE"), "TOTAL_REVENUE_1997")

# %%
total_1997.join(total_1998, total_1997.L_SHIPMODE == total_1998.L_SHIPMODE).show()
# Out:
# -------------------------------------------------------------------------------------------
# |"l_oshb_L_SHIPMODE"  |"TOTAL_REVENUE_1997"  |"r_y70y_L_SHIPMODE"  |"TOTAL_REVENUE_1998"  |
# -------------------------------------------------------------------------------------------
# |TRUCK                |1590733688302.036700  |TRUCK                |1197327971050.476000  |
# |REG AIR              |1588413005265.937100  |REG AIR              |1197951763139.771600  |
# |AIR                  |1588489012314.814700  |AIR                  |1198501334545.354000  |
# |SHIP                 |1587705642771.441000  |SHIP                 |1198711220773.695500  |
# |RAIL                 |1593265749227.381000  |RAIL                 |1196094347242.170000  |
# |MAIL                 |1589584697330.409300  |MAIL                 |1198424237452.120300  |
# |FOB                  |1588274810649.676300  |FOB                  |1192940262362.108000  |
# -------------------------------------------------------------------------------------------

# %%
joined_dfs = total_1997.join(total_1998, total_1997.L_SHIPMODE == total_1998.L_SHIPMODE).select(
    total_1997.col("L_SHIPMODE").alias("SHIPMODE"),
    "TOTAL_REVENUE_1997",
    "TOTAL_REVENUE_1998",
)

# %%
joined_dfs.show()
# Out:
# ------------------------------------------------------------
# |"SHIPMODE"  |"TOTAL_REVENUE_1997"  |"TOTAL_REVENUE_1998"  |
# ------------------------------------------------------------
# |AIR         |1588489012314.814700  |1198501334545.354000  |
# |TRUCK       |1590733688302.036700  |1197327971050.476000  |
# |MAIL        |1589584697330.409300  |1198424237452.120300  |
# |RAIL        |1593265749227.381000  |1196094347242.170000  |
# |SHIP        |1587705642771.441000  |1198711220773.695500  |
# |REG AIR     |1588413005265.937100  |1197951763139.771600  |
# |FOB         |1588274810649.676300  |1192940262362.108000  |
# ------------------------------------------------------------

# %% [markdown]
# ### Functions

# %%
joined_dfs.with_column(
    "TOTALS",
    functions.array_construct(
        functions.col("TOTAL_REVENUE_1997"), functions.col("TOTAL_REVENUE_1998")
    )
).show()
# Out:
# ------------------------------------------------------------------------------------
# |"SHIPMODE"  |"TOTAL_REVENUE_1997"  |"TOTAL_REVENUE_1998"  |"TOTALS"               |
# ------------------------------------------------------------------------------------
# |TRUCK       |1590733688302.036700  |1197327971050.476000  |[                      |
# |            |                      |                      |  1590733688302.0367,  |
# |            |                      |                      |  1197327971050.476    |
# |            |                      |                      |]                      |
# |SHIP        |1587705642771.441000  |1198711220773.695500  |[                      |
# |            |                      |                      |  1587705642771.441,   |
# |            |                      |                      |  1198711220773.6955   |
# |            |                      |                      |]                      |
# |MAIL        |1589584697330.409300  |1198424237452.120300  |[                      |
# |            |                      |                      |  1589584697330.4093,  |
# |            |                      |                      |  1198424237452.1203   |
# |            |                      |                      |]                      |
# |RAIL        |1593265749227.381000  |1196094347242.170000  |[                      |
# |            |                      |                      |  1593265749227.381,   |
# |            |                      |                      |  1196094347242.17     |
# |            |                      |                      |]                      |
# |FOB         |1588274810649.676300  |1192940262362.108000  |[                      |
# |            |                      |                      |  1588274810649.6763,  |
# |            |                      |                      |  1192940262362.108    |
# |            |                      |                      |]                      |
# |REG AIR     |1588413005265.937100  |1197951763139.771600  |[                      |
# |            |                      |                      |  1588413005265.9371,  |
# |            |                      |                      |  1197951763139.7716   |
# |            |                      |                      |]                      |
# |AIR         |1588489012314.814700  |1198501334545.354000  |[                      |
# |            |                      |                      |  1588489012314.8147,  |
# |            |                      |                      |  1198501334545.354    |
# |            |                      |                      |]                      |
# ------------------------------------------------------------------------------------

# %%
(
    joined_dfs.with_column(
        "TOTALS",
        functions.array_construct(
            functions.col("TOTAL_REVENUE_1997"), functions.col("TOTAL_REVENUE_1998")
        )
    )
    .with_column(
        "COMMENT",
        functions.concat(functions.lit("This logic was created by "), functions.current_user())
    )
    .with_column(
        "TRUST_LEVEL",
        functions.when(functions.col("SHIPMODE") == "REG AIR", 0.4)
        .when(functions.col("SHIPMODE") == "AIR", 0.6)
        .otherwise(1.0)
    )
).show()
# Out:
# -------------------------------------------------------------------------------------------------------------------------------------------
# |"SHIPMODE"  |"TOTAL_REVENUE_1997"  |"TOTAL_REVENUE_1998"  |"TOTALS"               |"COMMENT"                             |"TRUST_LEVEL"  |
# -------------------------------------------------------------------------------------------------------------------------------------------
# |FOB         |1588274810649.676300  |1192940262362.108000  |[                      |This logic was created by PAUL_LUCAS  |1.0            |
# |            |                      |                      |  1588274810649.6763,  |                                      |               |
# |            |                      |                      |  1192940262362.108    |                                      |               |
# |            |                      |                      |]                      |                                      |               |
# |TRUCK       |1590733688302.036700  |1197327971050.476000  |[                      |This logic was created by PAUL_LUCAS  |1.0            |
# |            |                      |                      |  1590733688302.0367,  |                                      |               |
# |            |                      |                      |  1197327971050.476    |                                      |               |
# |            |                      |                      |]                      |                                      |               |
# |MAIL        |1589584697330.409300  |1198424237452.120300  |[                      |This logic was created by PAUL_LUCAS  |1.0            |
# |            |                      |                      |  1589584697330.4093,  |                                      |               |
# |            |                      |                      |  1198424237452.1203   |                                      |               |
# |            |                      |                      |]                      |                                      |               |
# |RAIL        |1593265749227.381000  |1196094347242.170000  |[                      |This logic was created by PAUL_LUCAS  |1.0            |
# |            |                      |                      |  1593265749227.381,   |                                      |               |
# |            |                      |                      |  1196094347242.17     |                                      |               |
# |            |                      |                      |]                      |                                      |               |
# |SHIP        |1587705642771.441000  |1198711220773.695500  |[                      |This logic was created by PAUL_LUCAS  |1.0            |
# |            |                      |                      |  1587705642771.441,   |                                      |               |
# |            |                      |                      |  1198711220773.6955   |                                      |               |
# |            |                      |                      |]                      |                                      |               |
# |REG AIR     |1588413005265.937100  |1197951763139.771600  |[                      |This logic was created by PAUL_LUCAS  |0.4            |
# |            |                      |                      |  1588413005265.9371,  |                                      |               |
# |            |                      |                      |  1197951763139.7716   |                                      |               |
# |            |                      |                      |]                      |                                      |               |
# |AIR         |1588489012314.814700  |1198501334545.354000  |[                      |This logic was created by PAUL_LUCAS  |0.6            |
# |            |                      |                      |  1588489012314.8147,  |                                      |               |
# |            |                      |                      |  1198501334545.354    |                                      |               |
# |            |                      |                      |]                      |                                      |               |
# -------------------------------------------------------------------------------------------------------------------------------------------

# %%
joined_dfs = (
    joined_dfs.with_column(
        "TOTALS",
        functions.array_construct(
            functions.col("TOTAL_REVENUE_1997"), functions.col("TOTAL_REVENUE_1998")
        )
    )
    .with_column(
        "COMMENT",
        functions.concat(functions.lit("This logic was created by "), functions.current_user())
    )
    .with_column(
        "TRUST_LEVEL",
        functions.when(functions.col("SHIPMODE") == "REG AIR", 0.4)
        .when(functions.col("SHIPMODE") == "AIR", 0.6)
        .otherwise(1.0)
    )
)

# %%
joined_dfs.show()
# Out:
# -------------------------------------------------------------------------------------------------------------------------------------------
# |"SHIPMODE"  |"TOTAL_REVENUE_1997"  |"TOTAL_REVENUE_1998"  |"TOTALS"               |"COMMENT"                             |"TRUST_LEVEL"  |
# -------------------------------------------------------------------------------------------------------------------------------------------
# |FOB         |1588274810649.676300  |1192940262362.108000  |[                      |This logic was created by PAUL_LUCAS  |1.0            |
# |            |                      |                      |  1588274810649.6763,  |                                      |               |
# |            |                      |                      |  1192940262362.108    |                                      |               |
# |            |                      |                      |]                      |                                      |               |
# |TRUCK       |1590733688302.036700  |1197327971050.476000  |[                      |This logic was created by PAUL_LUCAS  |1.0            |
# |            |                      |                      |  1590733688302.0367,  |                                      |               |
# |            |                      |                      |  1197327971050.476    |                                      |               |
# |            |                      |                      |]                      |                                      |               |
# |MAIL        |1589584697330.409300  |1198424237452.120300  |[                      |This logic was created by PAUL_LUCAS  |1.0            |
# |            |                      |                      |  1589584697330.4093,  |                                      |               |
# |            |                      |                      |  1198424237452.1203   |                                      |               |
# |            |                      |                      |]                      |                                      |               |
# |RAIL        |1593265749227.381000  |1196094347242.170000  |[                      |This logic was created by PAUL_LUCAS  |1.0            |
# |            |                      |                      |  1593265749227.381,   |                                      |               |
# |            |                      |                      |  1196094347242.17     |                                      |               |
# |            |                      |                      |]                      |                                      |               |
# |SHIP        |1587705642771.441000  |1198711220773.695500  |[                      |This logic was created by PAUL_LUCAS  |1.0            |
# |            |                      |                      |  1587705642771.441,   |                                      |               |
# |            |                      |                      |  1198711220773.6955   |                                      |               |
# |            |                      |                      |]                      |                                      |               |
# |REG AIR     |1588413005265.937100  |1197951763139.771600  |[                      |This logic was created by PAUL_LUCAS  |0.4            |
# |            |                      |                      |  1588413005265.9371,  |                                      |               |
# |            |                      |                      |  1197951763139.7716   |                                      |               |
# |            |                      |                      |]                      |                                      |               |
# |AIR         |1588489012314.814700  |1198501334545.354000  |[                      |This logic was created by PAUL_LUCAS  |0.6            |
# |            |                      |                      |  1588489012314.8147,  |                                      |               |
# |            |                      |                      |  1198501334545.354    |                                      |               |
# |            |                      |                      |]                      |                                      |               |
# -------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Drop Column

# %%
joined_dfs = joined_dfs.drop("TOTAL_REVENUE_1997").drop("TOTAL_REVENUE_1998")

# %%
joined_dfs.show()
# Out:
# ---------------------------------------------------------------------------------------------
# |"SHIPMODE"  |"TOTALS"               |"COMMENT"                             |"TRUST_LEVEL"  |
# ---------------------------------------------------------------------------------------------
# |FOB         |[                      |This logic was created by PAUL_LUCAS  |1.0            |
# |            |  1588274810649.6763,  |                                      |               |
# |            |  1192940262362.108    |                                      |               |
# |            |]                      |                                      |               |
# |AIR         |[                      |This logic was created by PAUL_LUCAS  |0.6            |
# |            |  1588489012314.8147,  |                                      |               |
# |            |  1198501334545.354    |                                      |               |
# |            |]                      |                                      |               |
# |TRUCK       |[                      |This logic was created by PAUL_LUCAS  |1.0            |
# |            |  1590733688302.0367,  |                                      |               |
# |            |  1197327971050.476    |                                      |               |
# |            |]                      |                                      |               |
# |REG AIR     |[                      |This logic was created by PAUL_LUCAS  |0.4            |
# |            |  1588413005265.9371,  |                                      |               |
# |            |  1197951763139.7716   |                                      |               |
# |            |]                      |                                      |               |
# |SHIP        |[                      |This logic was created by PAUL_LUCAS  |1.0            |
# |            |  1587705642771.441,   |                                      |               |
# |            |  1198711220773.6955   |                                      |               |
# |            |]                      |                                      |               |
# |MAIL        |[                      |This logic was created by PAUL_LUCAS  |1.0            |
# |            |  1589584697330.4093,  |                                      |               |
# |            |  1198424237452.1203   |                                      |               |
# |            |]                      |                                      |               |
# |RAIL        |[                      |This logic was created by PAUL_LUCAS  |1.0            |
# |            |  1593265749227.381,   |                                      |               |
# |            |  1196094347242.17     |                                      |               |
# |            |]                      |                                      |               |
# ---------------------------------------------------------------------------------------------

# %% [markdown]
# ### Close Session

# %%
sp_session.close()
