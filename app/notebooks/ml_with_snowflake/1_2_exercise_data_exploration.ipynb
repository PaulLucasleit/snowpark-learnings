# %%
# Add module folder to notebook
import os
import sys

from dotenv import find_dotenv
sys.path.append(os.path.dirname(find_dotenv()))

# %%
from snowflake.snowpark import functions
import datetime

from app.snowpark_session.session import snowpark_session

# %%
session = snowpark_session()

session.use_database("HOL_DB")

# %%
print(f"Current Database and schema: {session.get_fully_qualified_current_schema()}")
print(f"Current Warehouse: {session.get_current_warehouse()}")
# Out:
# Current Database and schema: "HOL_DB"."PUBLIC"
# Current Warehouse: "LEIT_WH"

# %%
snowpark_df = session.table('APPLICATION_RECORD')

# %%
snowpark_df.limit(10).to_pandas()
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
# 5  5008810           F            N               Y             0
# 6  5008811           F            N               Y             0
# 7  5008812           F            N               Y             0
# 8  5008813           F            N               Y             0
# 9  5008814           F            N               Y             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
# 5          270000.0  Commercial associate  Secondary / secondary special
# 6          270000.0  Commercial associate  Secondary / secondary special
# 7          283500.0             Pensioner               Higher education
# 8          283500.0             Pensioner               Higher education
# 9          283500.0             Pensioner               Higher education
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0        Civil marriage   Rented apartment      -12005          -4542
# 1        Civil marriage   Rented apartment      -12005          -4542
# 2               Married  House / apartment      -21474          -1134
# 3  Single / not married  House / apartment      -19110          -3051
# 4  Single / not married  House / apartment      -19110          -3051
# 5  Single / not married  House / apartment      -19110          -3051
# 6  Single / not married  House / apartment      -19110          -3051
# 7             Separated  House / apartment      -22464         365243
# 8             Separated  House / apartment      -22464         365243
# 9             Separated  House / apartment      -22464         365243
#
#    FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 0           1                1           0           0            None
# 1           1                1           0           0            None
# 2           1                0           0           0  Security staff
# 3           1                0           1           1     Sales staff
# 4           1                0           1           1     Sales staff
# 5           1                0           1           1     Sales staff
# 6           1                0           1           1     Sales staff
# 7           1                0           0           0            None
# 8           1                0           0           0            None
# 9           1                0           0           0            None
#
#    CNT_FAM_MEMBERS
# 0              2.0
# 1              2.0
# 2              2.0
# 3              1.0
# 4              1.0
# 5              1.0
# 6              1.0
# 7              1.0
# 8              1.0
# 9              1.0

# %% [markdown]
# ## EXERCISE: Answer the following Questions

# %% [markdown]
# How many variables (columns) does the dataset have?

# %%
len(snowpark_df.columns)
# Out:
# 18

# %% [markdown]
# How many variables (columns) does the dataset have?

# %%
snowpark_df.count()
# Out:
# 438557

# %% [markdown]
# What is the average income?

# %%
snowpark_df.agg(functions.avg('AMT_INCOME_TOTAL').as_('AVG_AMT_INCOME_TOTAL')).show()
# Out:
# --------------------------
# |"AVG_AMT_INCOME_TOTAL"  |
# --------------------------
# |187524.2860095039       |
# --------------------------

# %% [markdown]
# How many people are Single?

# %%
snowpark_df.filter(functions.col('NAME_FAMILY_STATUS') == 'Single / not married').count()
# Out:
# 55271

# %% [markdown]
# ## EXERCISE: Create / Drop Features

# %% [markdown]
# Create a new feature containing the years of
#  Formula: Absolute Value of DAYS_EMPLOYED divided by 365 days rounded down

# %%
snowpark_df = snowpark_df.withColumn('YEARS_OF_EMPLOYMENT', functions.floor(functions.abs(functions.col('DAYS_EMPLOYED')) / 365))
snowpark_df.select(['ID', 'DAYS_EMPLOYED', 'YEARS_OF_EMPLOYMENT']).limit(10).to_pandas()
# Out:
#         ID  DAYS_EMPLOYED  YEARS_OF_EMPLOYMENT
# 0  5008804          -4542                   12
# 1  5008805          -4542                   12
# 2  5008806          -1134                    3
# 3  5008808          -3051                    8
# 4  5008809          -3051                    8
# 5  5008810          -3051                    8
# 6  5008811          -3051                    8
# 7  5008812         365243                 1000
# 8  5008813         365243                 1000
# 9  5008814         365243                 1000

# %% [markdown]
# Drop the variable DAYS_EMPLOYED

# %%
snowpark_df = snowpark_df.drop('DAYS_EMPLOYED')

# %%
snowpark_df.limit(20).to_pandas()
# Out:
#          ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0   5008804           M            Y               Y             0
# 1   5008805           M            Y               Y             0
# 2   5008806           M            Y               Y             0
# 3   5008808           F            N               Y             0
# 4   5008809           F            N               Y             0
# 5   5008810           F            N               Y             0
# 6   5008811           F            N               Y             0
# 7   5008812           F            N               Y             0
# 8   5008813           F            N               Y             0
# 9   5008814           F            N               Y             0
# 10  5008815           M            Y               Y             0
# 11  5112956           M            Y               Y             0
# 12  6153651           M            Y               Y             0
# 13  5008819           M            Y               Y             0
# 14  5008820           M            Y               Y             0
# 15  5008821           M            Y               Y             0
# 16  5008822           M            Y               Y             0
# 17  5008823           M            Y               Y             0
# 18  5008824           M            Y               Y             0
# 19  5008825           F            Y               N             0
#
#     AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0           427500.0               Working               Higher education
# 1           427500.0               Working               Higher education
# 2           112500.0               Working  Secondary / secondary special
# 3           270000.0  Commercial associate  Secondary / secondary special
# 4           270000.0  Commercial associate  Secondary / secondary special
# 5           270000.0  Commercial associate  Secondary / secondary special
# 6           270000.0  Commercial associate  Secondary / secondary special
# 7           283500.0             Pensioner               Higher education
# 8           283500.0             Pensioner               Higher education
# 9           283500.0             Pensioner               Higher education
# 10          270000.0               Working               Higher education
# 11          270000.0               Working               Higher education
# 12          270000.0               Working               Higher education
# 13          135000.0  Commercial associate  Secondary / secondary special
# 14          135000.0  Commercial associate  Secondary / secondary special
# 15          135000.0  Commercial associate  Secondary / secondary special
# 16          135000.0  Commercial associate  Secondary / secondary special
# 17          135000.0  Commercial associate  Secondary / secondary special
# 18          135000.0  Commercial associate  Secondary / secondary special
# 19          130500.0               Working              Incomplete higher
#
#       NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  FLAG_MOBIL  \
# 0         Civil marriage   Rented apartment      -12005           1
# 1         Civil marriage   Rented apartment      -12005           1
# 2                Married  House / apartment      -21474           1
# 3   Single / not married  House / apartment      -19110           1
# 4   Single / not married  House / apartment      -19110           1
# 5   Single / not married  House / apartment      -19110           1
# 6   Single / not married  House / apartment      -19110           1
# 7              Separated  House / apartment      -22464           1
# 8              Separated  House / apartment      -22464           1
# 9              Separated  House / apartment      -22464           1
# 10               Married  House / apartment      -16872           1
# 11               Married  House / apartment      -16872           1
# 12               Married  House / apartment      -16872           1
# 13               Married  House / apartment      -17778           1
# 14               Married  House / apartment      -17778           1
# 15               Married  House / apartment      -17778           1
# 16               Married  House / apartment      -17778           1
# 17               Married  House / apartment      -17778           1
# 18               Married  House / apartment      -17778           1
# 19               Married  House / apartment      -10669           1
#
#     FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  CNT_FAM_MEMBERS  \
# 0                 1           0           0            None              2.0
# 1                 1           0           0            None              2.0
# 2                 0           0           0  Security staff              2.0
# 3                 0           1           1     Sales staff              1.0
# 4                 0           1           1     Sales staff              1.0
# 5                 0           1           1     Sales staff              1.0
# 6                 0           1           1     Sales staff              1.0
# 7                 0           0           0            None              1.0
# 8                 0           0           0            None              1.0
# 9                 0           0           0            None              1.0
# 10                1           1           1     Accountants              2.0
# 11                1           1           1     Accountants              2.0
# 12                1           1           1     Accountants              2.0
# 13                0           0           0        Laborers              2.0
# 14                0           0           0        Laborers              2.0
# 15                0           0           0        Laborers              2.0
# 16                0           0           0        Laborers              2.0
# 17                0           0           0        Laborers              2.0
# 18                0           0           0        Laborers              2.0
# 19                0           0           0     Accountants              2.0
#
#     YEARS_OF_EMPLOYMENT
# 0                    12
# 1                    12
# 2                     3
# 3                     8
# 4                     8
# 5                     8
# 6                     8
# 7                  1000
# 8                  1000
# 9                  1000
# 10                    2
# 11                    2
# 12                    2
# 13                    3
# 14                    3
# 15                    3
# 16                    3
# 17                    3
# 18                    3
# 19                    3

# %%
session.close()
